# %% [markdown]
# ## Version 2 - Boss/client feedback
# Oh no, the client has taken a look at our work and they are not happy.
# They spend a lot of money on that data and we have thrown away two whole columns without good reason.
# We need to update our feature engineering to include features based on the cabin and name columns,
# which should also hopefully improve the performance since they feel 74% is a little too low to put into production.
# Also the client doesn't know what to do with a .cbm file, they just want to be able to get new predictions whenever they get new data coming in.
# Let's first implement the new features so that we use the dropped columns and then we can think about getting the predictions to the client somehow.

# %%
# !pip install catboost matplotlib pandas scikit-learn kaggle optuna ipywidgets kaleido shap
# Out:
# Requirement already satisfied: catboost in c:\users\claus\venvs\arisa\lib\site-packages (1.2.7)
# Requirement already satisfied: matplotlib in c:\users\claus\venvs\arisa\lib\site-packages (3.10.0)
# Requirement already satisfied: pandas in c:\users\claus\venvs\arisa\lib\site-packages (2.2.3)
# Requirement already satisfied: scikit-learn in c:\users\claus\venvs\arisa\lib\site-packages (1.6.1)
# Requirement already satisfied: kaggle in c:\users\claus\venvs\arisa\lib\site-packages (1.6.17)
# Requirement already satisfied: optuna in c:\users\claus\venvs\arisa\lib\site-packages (4.2.0)
# Requirement already satisfied: ipywidgets in c:\users\claus\venvs\arisa\lib\site-packages (8.1.5)
# Requirement already satisfied: kaleido in c:\users\claus\venvs\arisa\lib\site-packages (0.2.1)
# Requirement already satisfied: shap in c:\users\claus\venvs\arisa\lib\site-packages (0.46.0)
# Requirement already satisfied: graphviz in c:\users\claus\venvs\arisa\lib\site-packages (from catboost) (0.20.3)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in c:\users\claus\venvs\arisa\lib\site-packages (from catboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\claus\venvs\arisa\lib\site-packages (from catboost) (1.15.1)
# Requirement already satisfied: plotly in c:\users\claus\venvs\arisa\lib\site-packages (from catboost) (6.0.0)
# Requirement already satisfied: six in c:\users\claus\venvs\arisa\lib\site-packages (from catboost) (1.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\claus\venvs\arisa\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\claus\venvs\arisa\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\claus\venvs\arisa\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\claus\venvs\arisa\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\claus\venvs\arisa\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\claus\venvs\arisa\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\claus\venvs\arisa\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\claus\venvs\arisa\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\claus\venvs\arisa\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\claus\venvs\arisa\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\claus\venvs\arisa\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\claus\venvs\arisa\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: certifi>=2023.7.22 in c:\users\claus\venvs\arisa\lib\site-packages (from kaggle) (2025.1.31)
# Requirement already satisfied: requests in c:\users\claus\venvs\arisa\lib\site-packages (from kaggle) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\claus\venvs\arisa\lib\site-packages (from kaggle) (4.67.1)
# Requirement already satisfied: python-slugify in c:\users\claus\venvs\arisa\lib\site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in c:\users\claus\venvs\arisa\lib\site-packages (from kaggle) (2.3.0)
# Requirement already satisfied: bleach in c:\users\claus\venvs\arisa\lib\site-packages (from kaggle) (6.2.0)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\claus\venvs\arisa\lib\site-packages (from optuna) (1.14.1)
# Requirement already satisfied: colorlog in c:\users\claus\venvs\arisa\lib\site-packages (from optuna) (6.9.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\users\claus\venvs\arisa\lib\site-packages (from optuna) (2.0.38)
# Requirement already satisfied: PyYAML in c:\users\claus\venvs\arisa\lib\site-packages (from optuna) (6.0.2)
# Requirement already satisfied: comm>=0.1.3 in c:\users\claus\venvs\arisa\lib\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\claus\venvs\arisa\lib\site-packages (from ipywidgets) (8.32.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\claus\venvs\arisa\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\claus\venvs\arisa\lib\site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\claus\venvs\arisa\lib\site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: slicer==0.0.8 in c:\users\claus\venvs\arisa\lib\site-packages (from shap) (0.0.8)
# Requirement already satisfied: numba in c:\users\claus\venvs\arisa\lib\site-packages (from shap) (0.61.0)
# Requirement already satisfied: cloudpickle in c:\users\claus\venvs\arisa\lib\site-packages (from shap) (3.1.1)
# Requirement already satisfied: Mako in c:\users\claus\venvs\arisa\lib\site-packages (from alembic>=1.5.0->optuna) (1.3.9)
# Requirement already satisfied: typing-extensions>=4 in c:\users\claus\venvs\arisa\lib\site-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: colorama in c:\users\claus\venvs\arisa\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator in c:\users\claus\venvs\arisa\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\claus\venvs\arisa\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\claus\venvs\arisa\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\claus\venvs\arisa\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\claus\venvs\arisa\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\claus\venvs\arisa\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\claus\venvs\arisa\lib\site-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: webencodings in c:\users\claus\venvs\arisa\lib\site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\claus\venvs\arisa\lib\site-packages (from numba->shap) (0.44.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\claus\venvs\arisa\lib\site-packages (from plotly->catboost) (1.25.2)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\claus\venvs\arisa\lib\site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\claus\venvs\arisa\lib\site-packages (from requests->kaggle) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\claus\venvs\arisa\lib\site-packages (from requests->kaggle) (3.10)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\claus\venvs\arisa\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\claus\venvs\arisa\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\claus\venvs\arisa\lib\site-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Requirement already satisfied: executing>=1.2.0 in c:\users\claus\venvs\arisa\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\claus\venvs\arisa\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\claus\venvs\arisa\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# [notice] A new release of pip is available: 24.0 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Getting the data again.

# %%
import os
import zipfile
from pathlib import Path
from kaggle.api.kaggle_api_extended import KaggleApi

api = KaggleApi()
api.authenticate()

dataset = "titanic"  # original competition dataset
dataset_test = "wesleyhowe/titanic-labelled-test-set"  # test set augmented with target labels
download_folder = Path("data/titanic")
zip_path = download_folder / "titanic.zip"
download_folder.mkdir(parents=True, exist_ok=True)

api.competition_download_files(dataset, path=str(download_folder))
api.dataset_download_files(dataset_test, path=str(download_folder), unzip=True)

with zipfile.ZipFile(zip_path, "r") as zip_ref:
    zip_ref.extractall(str(download_folder))

os.remove(zip_path)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/wesleyhowe/titanic-labelled-test-set

# %%
# !dir "./data/titanic"
# Out:
#  Volume in drive D has no label.
#  Volume Serial Number is 294C-6643
#
#  Directory of d:\sdev\wwsi\arisa\ARISA-MLOps\data\titanic
#
# 18.05.2025  16:41    <DIR>          .
# 18.05.2025  16:41    <DIR>          ..
# 18.05.2025  16:41             3�258 gender_submission.csv
# 18.05.2025  16:41            28�629 test.csv
# 18.05.2025  16:41            30�234 test_augmented.csv
# 18.05.2025  16:41            61�194 train.csv
#                4 File(s)        123�315 bytes
#                2 Dir(s)  263�541�927�936 bytes free

# %% [markdown]
# Read in the data again and dropping passengerId, and now only ticket, since we will be using Name and Cabin.

# %%
import pandas as pd

df_train = pd.read_csv(download_folder / "train.csv")
df_ids = df_train.pop("PassengerId")  # set aside PassengerId

df_train.sample(10)

df_train = df_train.drop(columns=["Ticket"])
df_train.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0    male  22.0      1      0   7.2500   NaN        S
# 1  female  38.0      1      0  71.2833   C85        C
# 2  female  26.0      0      0   7.9250   NaN        S
# 3  female  35.0      1      0  53.1000  C123        S
# 4    male  35.0      0      0   8.0500   NaN        S

# %% [markdown]
# Quick regex match on the titles

# %%
import re
def extract_title(name):
    match = re.search(r',\s*([\w\s]+)\.', name)
    return match.group(1) if match else None
df_train["Title"] = df_train["Name"].apply(extract_title)
df_train.sample(5)
# Out:
#      Survived  Pclass                                         Name     Sex  \
# 15          1       2             Hewlett, Mrs. (Mary D Kingcome)   female
# 726         1       2  Renouf, Mrs. Peter Henry (Lillian Jefferys)  female
# 340         1       2               Navratil, Master. Edmond Roger    male
# 66          1       2                 Nye, Mrs. (Elizabeth Ramell)  female
# 134         0       2               Sobey, Mr. Samuel James Hayden    male
#
#       Age  SibSp  Parch  Fare Cabin Embarked   Title
# 15   55.0      0      0  16.0   NaN        S     Mrs
# 726  30.0      3      0  21.0   NaN        S     Mrs
# 340   2.0      1      1  26.0    F2        S  Master
# 66   29.0      0      0  10.5   F33        S     Mrs
# 134  25.0      0      0  13.0   NaN        S      Mr

# %% [markdown]
# Looks about right:

# %%
df_train["Title"].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
#        'Major', 'Lady', 'Sir', 'Mlle', 'Col', 'Capt', 'the Countess',
#        'Jonkheer'], dtype=object)

# %% [markdown]
# And for the Cabin we split into deck and cabin number:

# %%
# pattern to match a letter followed by a number
pattern = r'([A-Za-z]+)(\d+)'

# run pattern on Cabin to extract all matches
matches = df_train['Cabin'].str.extractall(pattern)
matches.reset_index(inplace=True)

# create a new column for each letter and number matched
result = matches.pivot(index='level_0', columns='match', values=[0, 1])
result.columns = [f"{col[0]}_{col[1]}" for col in result.columns]

# join to original train dataframe
df_train = df_train.join(result[["0_0", "1_0"]])

# fill nans
df_train["1_0"] = df_train["1_0"].astype(float)
df_train = df_train.fillna({"0_0": "N", "1_0": df_train["1_0"].mean()})
df_train["1_0"] = df_train["1_0"].astype(int)

# rename new columns and drop old ones
df_train = df_train.rename(columns={"0_0": "Deck", "1_0": "CabinNumber"})
df_train.drop(columns=["Cabin", "Name"], axis=1, inplace=True)

# %%
df_train.sample(10)
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare Embarked Title  \
# 187         1       1    male  45.0      0      0   26.5500        S    Mr
# 253         0       3    male  30.0      1      0   16.1000        S    Mr
# 768         0       3    male   NaN      1      0   24.1500        Q    Mr
# 712         1       1    male  48.0      1      0   52.0000        S    Mr
# 503         0       3  female  37.0      0      0    9.5875        S  Miss
# 11          1       1  female  58.0      0      0   26.5500        S  Miss
# 93          0       3    male  26.0      1      2   20.5750        S    Mr
# 865         1       2  female  42.0      0      0   13.0000        S   Mrs
# 31          1       1  female   NaN      1      0  146.5208        C   Mrs
# 812         0       2    male  35.0      0      0   10.5000        S    Mr
#
#     Deck  CabinNumber
# 187    N           50
# 253    N           50
# 768    N           50
# 712    C          126
# 503    N           50
# 11     C          103
# 93     N           50
# 865    N           50
# 31     B           78
# 812    N           50

# %% [markdown]
# Fill remaining nans:

# %%
df_train = df_train.fillna({"Embarked": "N", "Age": df_train["Age"].mean()})
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Survived     891 non-null    int64
#  1   Pclass       891 non-null    int64
#  2   Sex          891 non-null    object
#  3   Age          891 non-null    float64
#  4   SibSp        891 non-null    int64
#  5   Parch        891 non-null    int64
#  6   Fare         891 non-null    float64
#  7   Embarked     891 non-null    object
#  8   Title        891 non-null    object
#  9   Deck         891 non-null    object
#  10  CabinNumber  891 non-null    int32
# dtypes: float64(2), int32(1), int64(4), object(4)
# memory usage: 73.2+ KB

# %% [markdown]
# Get indices for categorical columns now including Title and Deck (CabinNumber is numerical):

# %%
categorical = [
    "Pclass", 
    "Sex", 
    "Embarked",
    "Deck",
    "Title"
]

y_train = df_train.pop("Survived")
X_train = df_train

categorical_indices = [X_train.columns.get_loc(col) for col in categorical if col in X_train.columns]
categorical_indices
# Out:
# [0, 1, 6, 8, 7]

# %% [markdown]
# And run the hyperparameter optimization:

# %%
import joblib
import optuna
from sklearn.model_selection import train_test_split
from catboost import CatBoostClassifier, Pool, cv

outfolder = Path("results")
outfolder.mkdir(parents=True, exist_ok=True)

best_params_path = outfolder / "best_params_v2.pkl"

if not best_params_path.is_file():
    X_train_opt, X_val_opt, y_train_opt, y_val_opt = train_test_split(X_train, y_train, test_size=0.25, random_state=42)
    
    def objective(trial):
        params = {
            "depth": trial.suggest_int("depth", 2, 10),
            "learning_rate": trial.suggest_float("learning_rate", 1e-4, 0.3),
            "iterations": trial.suggest_int("iterations", 50, 300),
            "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1e-5, 100.0, log=True),
            "bagging_temperature": trial.suggest_float("bagging_temperature", 0.01, 1),
            "random_strength": trial.suggest_float("random_strength", 1e-5, 100.0, log=True)
        }
        model = CatBoostClassifier(**params, verbose=0)
        model.fit(X_train_opt, y_train_opt, eval_set=(X_val_opt, y_val_opt), cat_features=categorical_indices, early_stopping_rounds=50)
        return model.get_best_score()["validation"]["Logloss"]
    study = optuna.create_study(direction="minimize")
    study.optimize(objective, n_trials=50)
    
    joblib.dump(study.best_params, best_params_path)
    params = study.best_params
else:
    params = joblib.load(best_params_path)
print("Best Parameters:", params)
# Out:
# Best Parameters: {'depth': 4, 'learning_rate': 0.22006324169065175, 'iterations': 163, 'l2_leaf_reg': 0.031900004970318356, 'bagging_temperature': 0.5964381011651683, 'random_strength': 0.0013931822006011051}

# %% [markdown]
# Do cross validation again:

# %%
params["eval_metric"] = "F1"
params["loss_function"] = "Logloss"

model = CatBoostClassifier(
    **params,
    verbose=True
)

data = Pool(X_train, y_train, cat_features=categorical_indices)

cv_results = cv(
    params=params,
    pool=data,
    fold_count=5,
    partition_random_seed=42,
    shuffle=True,
)

cv_results.to_csv(outfolder / "cv_results_v2.csv", index=False)
# Out:
# Training on fold [0/5]
# 0:	learn: 0.7471264	test: 0.7692308	best: 0.7692308 (0)	total: 167ms	remaining: 27s
# 1:	learn: 0.7533461	test: 0.7938931	best: 0.7938931 (1)	total: 180ms	remaining: 14.5s
# 2:	learn: 0.7557252	test: 0.7938931	best: 0.7938931 (1)	total: 202ms	remaining: 10.8s
# 3:	learn: 0.7600768	test: 0.7938931	best: 0.7938931 (1)	total: 223ms	remaining: 8.85s
# 4:	learn: 0.7600768	test: 0.7938931	best: 0.7938931 (1)	total: 237ms	remaining: 7.49s
# 5:	learn: 0.7600768	test: 0.7938931	best: 0.7938931 (1)	total: 250ms	remaining: 6.54s
# 6:	learn: 0.7635659	test: 0.8000000	best: 0.8000000 (6)	total: 264ms	remaining: 5.89s
# 7:	learn: 0.7659574	test: 0.8000000	best: 0.8000000 (6)	total: 277ms	remaining: 5.36s
# 8:	learn: 0.7730769	test: 0.7938931	best: 0.8000000 (6)	total: 290ms	remaining: 4.96s
# 9:	learn: 0.7760618	test: 0.7938931	best: 0.8000000 (6)	total: 302ms	remaining: 4.62s
# 10:	learn: 0.7775629	test: 0.7938931	best: 0.8000000 (6)	total: 317ms	remaining: 4.39s
# 11:	learn: 0.7755906	test: 0.7906977	best: 0.8000000 (6)	total: 331ms	remaining: 4.17s
# 12:	learn: 0.7898833	test: 0.7906977	best: 0.8000000 (6)	total: 344ms	remaining: 3.97s
# 13:	learn: 0.7945736	test: 0.7906977	best: 0.8000000 (6)	total: 357ms	remaining: 3.8s
# 14:	learn: 0.8084291	test: 0.7906977	best: 0.8000000 (6)	total: 379ms	remaining: 3.74s
# 15:	learn: 0.8160920	test: 0.7968750	best: 0.8000000 (6)	total: 398ms	remaining: 3.65s
# 16:	learn: 0.8062622	test: 0.7840000	best: 0.8000000 (6)	total: 416ms	remaining: 3.57s
# 17:	learn: 0.8201161	test: 0.8031496	best: 0.8031496 (17)	total: 429ms	remaining: 3.45s
# 18:	learn: 0.8217054	test: 0.8031496	best: 0.8031496 (17)	total: 441ms	remaining: 3.35s
# 19:	learn: 0.8171206	test: 0.8031496	best: 0.8031496 (17)	total: 460ms	remaining: 3.29s
# 20:	learn: 0.8171206	test: 0.8031496	best: 0.8031496 (17)	total: 481ms	remaining: 3.25s
# 21:	learn: 0.8194175	test: 0.8125000	best: 0.8125000 (21)	total: 495ms	remaining: 3.17s
# 22:	learn: 0.8156863	test: 0.7840000	best: 0.8125000 (21)	total: 512ms	remaining: 3.12s
# 23:	learn: 0.8156863	test: 0.7903226	best: 0.8125000 (21)	total: 525ms	remaining: 3.04s
# 24:	learn: 0.8149606	test: 0.7840000	best: 0.8125000 (21)	total: 539ms	remaining: 2.98s
# 25:	learn: 0.8251473	test: 0.8095238	best: 0.8125000 (21)	total: 551ms	remaining: 2.9s
# 26:	learn: 0.8219178	test: 0.8095238	best: 0.8125000 (21)	total: 566ms	remaining: 2.85s
# 27:	learn: 0.8219178	test: 0.8095238	best: 0.8125000 (21)	total: 583ms	remaining: 2.81s
# 28:	learn: 0.8219178	test: 0.8095238	best: 0.8125000 (21)	total: 604ms	remaining: 2.79s
# 29:	learn: 0.8260870	test: 0.8372093	best: 0.8372093 (29)	total: 617ms	remaining: 2.73s
# 30:	learn: 0.8274510	test: 0.8372093	best: 0.8372093 (29)	total: 635ms	remaining: 2.7s
# 31:	learn: 0.8290766	test: 0.8372093	best: 0.8372093 (29)	total: 654ms	remaining: 2.68s
# 32:	learn: 0.8258317	test: 0.8281250	best: 0.8372093 (29)	total: 685ms	remaining: 2.7s
# 33:	learn: 0.8290766	test: 0.8461538	best: 0.8461538 (33)	total: 708ms	remaining: 2.69s
# 34:	learn: 0.8330059	test: 0.8461538	best: 0.8461538 (33)	total: 734ms	remaining: 2.69s
# 35:	learn: 0.8414873	test: 0.8461538	best: 0.8461538 (33)	total: 756ms	remaining: 2.67s
# 36:	learn: 0.8414873	test: 0.8461538	best: 0.8461538 (33)	total: 779ms	remaining: 2.65s
# 37:	learn: 0.8385827	test: 0.8461538	best: 0.8461538 (33)	total: 798ms	remaining: 2.62s
# 38:	learn: 0.8425197	test: 0.8396947	best: 0.8461538 (33)	total: 814ms	remaining: 2.59s
# 39:	learn: 0.8454012	test: 0.8396947	best: 0.8461538 (33)	total: 831ms	remaining: 2.56s
# 40:	learn: 0.8454012	test: 0.8307692	best: 0.8461538 (33)	total: 849ms	remaining: 2.53s
# 41:	learn: 0.8476562	test: 0.8307692	best: 0.8461538 (33)	total: 867ms	remaining: 2.5s
# 42:	learn: 0.8476562	test: 0.8372093	best: 0.8461538 (33)	total: 888ms	remaining: 2.48s
# 43:	learn: 0.8538012	test: 0.8372093	best: 0.8461538 (33)	total: 907ms	remaining: 2.45s
# 44:	learn: 0.8593750	test: 0.8372093	best: 0.8461538 (33)	total: 924ms	remaining: 2.42s
# 45:	learn: 0.8610568	test: 0.8372093	best: 0.8461538 (33)	total: 940ms	remaining: 2.39s
# 46:	learn: 0.8610568	test: 0.8281250	best: 0.8461538 (33)	total: 954ms	remaining: 2.35s
# 47:	learn: 0.8610568	test: 0.8188976	best: 0.8461538 (33)	total: 971ms	remaining: 2.33s
# 48:	learn: 0.8582677	test: 0.8281250	best: 0.8461538 (33)	total: 989ms	remaining: 2.3s
# 49:	learn: 0.8605108	test: 0.8000000	best: 0.8461538 (33)	total: 1s	remaining: 2.27s
# 50:	learn: 0.8610568	test: 0.7936508	best: 0.8461538 (33)	total: 1.02s	remaining: 2.24s
# 51:	learn: 0.8593750	test: 0.8031496	best: 0.8461538 (33)	total: 1.04s	remaining: 2.22s
# 52:	learn: 0.8632813	test: 0.8125000	best: 0.8461538 (33)	total: 1.06s	remaining: 2.2s
# 53:	learn: 0.8615984	test: 0.8125000	best: 0.8461538 (33)	total: 1.08s	remaining: 2.17s
# 54:	learn: 0.8638132	test: 0.8125000	best: 0.8461538 (33)	total: 1.09s	remaining: 2.15s
# 55:	learn: 0.8671875	test: 0.8031496	best: 0.8461538 (33)	total: 1.11s	remaining: 2.12s
# 56:	learn: 0.8715953	test: 0.8031496	best: 0.8461538 (33)	total: 1.12s	remaining: 2.09s
# 57:	learn: 0.8693957	test: 0.8031496	best: 0.8461538 (33)	total: 1.14s	remaining: 2.06s
# 58:	learn: 0.8759690	test: 0.8125000	best: 0.8461538 (33)	total: 1.16s	remaining: 2.04s
# 59:	learn: 0.8759690	test: 0.8031496	best: 0.8461538 (33)	total: 1.17s	remaining: 2.01s
# 60:	learn: 0.8759690	test: 0.7968750	best: 0.8461538 (33)	total: 1.19s	remaining: 1.98s
# 61:	learn: 0.8759690	test: 0.8031496	best: 0.8461538 (33)	total: 1.2s	remaining: 1.96s
# 62:	learn: 0.8781431	test: 0.8031496	best: 0.8461538 (33)	total: 1.22s	remaining: 1.93s
# 63:	learn: 0.8781431	test: 0.8031496	best: 0.8461538 (33)	total: 1.24s	remaining: 1.91s
# 64:	learn: 0.8798450	test: 0.8031496	best: 0.8461538 (33)	total: 1.25s	remaining: 1.88s
# 65:	learn: 0.8798450	test: 0.8031496	best: 0.8461538 (33)	total: 1.27s	remaining: 1.87s
# 66:	learn: 0.8798450	test: 0.8031496	best: 0.8461538 (33)	total: 1.29s	remaining: 1.84s
# 67:	learn: 0.8820116	test: 0.8031496	best: 0.8461538 (33)	total: 1.3s	remaining: 1.82s
# 68:	learn: 0.8820116	test: 0.8031496	best: 0.8461538 (33)	total: 1.32s	remaining: 1.8s
# 69:	learn: 0.8841699	test: 0.8031496	best: 0.8461538 (33)	total: 1.33s	remaining: 1.77s
# 70:	learn: 0.8837209	test: 0.8031496	best: 0.8461538 (33)	total: 1.35s	remaining: 1.74s
# 71:	learn: 0.8880309	test: 0.8031496	best: 0.8461538 (33)	total: 1.36s	remaining: 1.72s
# 72:	learn: 0.8880309	test: 0.8031496	best: 0.8461538 (33)	total: 1.37s	remaining: 1.69s
# 73:	learn: 0.8880309	test: 0.8031496	best: 0.8461538 (33)	total: 1.39s	remaining: 1.67s
# 74:	learn: 0.8932039	test: 0.8000000	best: 0.8461538 (33)	total: 1.4s	remaining: 1.64s
# 75:	learn: 0.8953488	test: 0.8031496	best: 0.8461538 (33)	total: 1.41s	remaining: 1.62s
# 76:	learn: 0.8932039	test: 0.8031496	best: 0.8461538 (33)	total: 1.43s	remaining: 1.59s
# 77:	learn: 0.8932039	test: 0.8031496	best: 0.8461538 (33)	total: 1.44s	remaining: 1.57s
# 78:	learn: 0.8953488	test: 0.8031496	best: 0.8461538 (33)	total: 1.46s	remaining: 1.55s
# 79:	learn: 0.8953488	test: 0.8031496	best: 0.8461538 (33)	total: 1.47s	remaining: 1.53s
# 80:	learn: 0.8974855	test: 0.7936508	best: 0.8461538 (33)	total: 1.49s	remaining: 1.51s
# 81:	learn: 0.8974855	test: 0.8031496	best: 0.8461538 (33)	total: 1.5s	remaining: 1.49s
# 82:	learn: 0.8932039	test: 0.8031496	best: 0.8461538 (33)	total: 1.52s	remaining: 1.46s
# 83:	learn: 0.8953488	test: 0.7936508	best: 0.8461538 (33)	total: 1.53s	remaining: 1.44s
# 84:	learn: 0.8974855	test: 0.7936508	best: 0.8461538 (33)	total: 1.55s	remaining: 1.42s
# 85:	learn: 0.8974855	test: 0.7936508	best: 0.8461538 (33)	total: 1.56s	remaining: 1.4s
# 86:	learn: 0.8974855	test: 0.7936508	best: 0.8461538 (33)	total: 1.58s	remaining: 1.38s
# 87:	learn: 0.9034749	test: 0.7874016	best: 0.8461538 (33)	total: 1.59s	remaining: 1.36s
# 88:	learn: 0.9034749	test: 0.7874016	best: 0.8461538 (33)	total: 1.61s	remaining: 1.34s
# 89:	learn: 0.9034749	test: 0.7874016	best: 0.8461538 (33)	total: 1.63s	remaining: 1.32s
# 90:	learn: 0.9076923	test: 0.7968750	best: 0.8461538 (33)	total: 1.64s	remaining: 1.3s
# 91:	learn: 0.9076923	test: 0.7968750	best: 0.8461538 (33)	total: 1.66s	remaining: 1.28s
# 92:	learn: 0.9076923	test: 0.7968750	best: 0.8461538 (33)	total: 1.67s	remaining: 1.26s
# 93:	learn: 0.9076923	test: 0.7968750	best: 0.8461538 (33)	total: 1.69s	remaining: 1.24s
# 94:	learn: 0.9076923	test: 0.7968750	best: 0.8461538 (33)	total: 1.7s	remaining: 1.22s
# 95:	learn: 0.9076923	test: 0.7906977	best: 0.8461538 (33)	total: 1.72s	remaining: 1.2s
# 96:	learn: 0.9097889	test: 0.7968750	best: 0.8461538 (33)	total: 1.74s	remaining: 1.18s
# 97:	learn: 0.9097889	test: 0.8062016	best: 0.8461538 (33)	total: 1.76s	remaining: 1.16s
# 98:	learn: 0.9097889	test: 0.8000000	best: 0.8461538 (33)	total: 1.77s	remaining: 1.15s
# 99:	learn: 0.9097889	test: 0.7906977	best: 0.8461538 (33)	total: 1.78s	remaining: 1.12s
# 100:	learn: 0.9118774	test: 0.7906977	best: 0.8461538 (33)	total: 1.8s	remaining: 1.1s
# 101:	learn: 0.9139579	test: 0.7906977	best: 0.8461538 (33)	total: 1.81s	remaining: 1.08s
# 102:	learn: 0.9139579	test: 0.7906977	best: 0.8461538 (33)	total: 1.83s	remaining: 1.07s
# 103:	learn: 0.9160305	test: 0.7906977	best: 0.8461538 (33)	total: 1.84s	remaining: 1.05s
# 104:	learn: 0.9198473	test: 0.7906977	best: 0.8461538 (33)	total: 1.86s	remaining: 1.03s
# 105:	learn: 0.9216061	test: 0.8000000	best: 0.8461538 (33)	total: 1.88s	remaining: 1.01s
# 106:	learn: 0.9216061	test: 0.8000000	best: 0.8461538 (33)	total: 1.9s	remaining: 994ms
# 107:	learn: 0.9216061	test: 0.8062016	best: 0.8461538 (33)	total: 1.92s	remaining: 976ms
# 108:	learn: 0.9216061	test: 0.8062016	best: 0.8461538 (33)	total: 1.93s	remaining: 956ms
# 109:	learn: 0.9236641	test: 0.8062016	best: 0.8461538 (33)	total: 1.95s	remaining: 938ms
# 110:	learn: 0.9195402	test: 0.8062016	best: 0.8461538 (33)	total: 1.96s	remaining: 919ms
# 111:	learn: 0.9236641	test: 0.8062016	best: 0.8461538 (33)	total: 1.98s	remaining: 900ms
# 112:	learn: 0.9236641	test: 0.8062016	best: 0.8461538 (33)	total: 1.99s	remaining: 882ms
# 113:	learn: 0.9236641	test: 0.8062016	best: 0.8461538 (33)	total: 2.01s	remaining: 864ms
# 114:	learn: 0.9257143	test: 0.8062016	best: 0.8461538 (33)	total: 2.02s	remaining: 845ms
# 115:	learn: 0.9257143	test: 0.8062016	best: 0.8461538 (33)	total: 2.04s	remaining: 826ms
# 116:	learn: 0.9257143	test: 0.8062016	best: 0.8461538 (33)	total: 2.06s	remaining: 809ms
# 117:	learn: 0.9257143	test: 0.8062016	best: 0.8461538 (33)	total: 2.07s	remaining: 791ms
# 118:	learn: 0.9318182	test: 0.8062016	best: 0.8461538 (33)	total: 2.09s	remaining: 773ms
# 119:	learn: 0.9318182	test: 0.8062016	best: 0.8461538 (33)	total: 2.11s	remaining: 755ms
# 120:	learn: 0.9335863	test: 0.7968750	best: 0.8461538 (33)	total: 2.13s	remaining: 738ms
# 121:	learn: 0.9353612	test: 0.8062016	best: 0.8461538 (33)	total: 2.14s	remaining: 719ms
# 122:	learn: 0.9335863	test: 0.8062016	best: 0.8461538 (33)	total: 2.15s	remaining: 701ms
# 123:	learn: 0.9353612	test: 0.8153846	best: 0.8461538 (33)	total: 2.17s	remaining: 684ms
# 124:	learn: 0.9353612	test: 0.8153846	best: 0.8461538 (33)	total: 2.19s	remaining: 667ms
# 125:	learn: 0.9353612	test: 0.8062016	best: 0.8461538 (33)	total: 2.21s	remaining: 649ms
# 126:	learn: 0.9373814	test: 0.8153846	best: 0.8461538 (33)	total: 2.23s	remaining: 632ms
# 127:	learn: 0.9393939	test: 0.8153846	best: 0.8461538 (33)	total: 2.24s	remaining: 613ms
# 128:	learn: 0.9431818	test: 0.8244275	best: 0.8461538 (33)	total: 2.26s	remaining: 595ms
# 129:	learn: 0.9431818	test: 0.8244275	best: 0.8461538 (33)	total: 2.27s	remaining: 577ms
# 130:	learn: 0.9471698	test: 0.8244275	best: 0.8461538 (33)	total: 2.29s	remaining: 559ms
# 131:	learn: 0.9491525	test: 0.8244275	best: 0.8461538 (33)	total: 2.31s	remaining: 542ms
# 132:	learn: 0.9491525	test: 0.8244275	best: 0.8461538 (33)	total: 2.32s	remaining: 524ms
# 133:	learn: 0.9509434	test: 0.8244275	best: 0.8461538 (33)	total: 2.34s	remaining: 506ms
# 134:	learn: 0.9529190	test: 0.8244275	best: 0.8461538 (33)	total: 2.35s	remaining: 488ms
# 135:	learn: 0.9547170	test: 0.8244275	best: 0.8461538 (33)	total: 2.37s	remaining: 471ms
# 136:	learn: 0.9527410	test: 0.8244275	best: 0.8461538 (33)	total: 2.39s	remaining: 454ms
# 137:	learn: 0.9547170	test: 0.8244275	best: 0.8461538 (33)	total: 2.4s	remaining: 436ms
# 138:	learn: 0.9566855	test: 0.8091603	best: 0.8461538 (33)	total: 2.42s	remaining: 417ms
# 139:	learn: 0.9566855	test: 0.8091603	best: 0.8461538 (33)	total: 2.43s	remaining: 400ms
# 140:	learn: 0.9489603	test: 0.8091603	best: 0.8461538 (33)	total: 2.45s	remaining: 383ms
# 141:	learn: 0.9586466	test: 0.8091603	best: 0.8461538 (33)	total: 2.47s	remaining: 365ms
# 142:	learn: 0.9566855	test: 0.8091603	best: 0.8461538 (33)	total: 2.48s	remaining: 347ms
# 143:	learn: 0.9547170	test: 0.8091603	best: 0.8461538 (33)	total: 2.5s	remaining: 330ms
# 144:	learn: 0.9547170	test: 0.8091603	best: 0.8461538 (33)	total: 2.52s	remaining: 313ms
# 145:	learn: 0.9547170	test: 0.8153846	best: 0.8461538 (33)	total: 2.54s	remaining: 295ms
# 146:	learn: 0.9547170	test: 0.8091603	best: 0.8461538 (33)	total: 2.55s	remaining: 278ms
# 147:	learn: 0.9566855	test: 0.8091603	best: 0.8461538 (33)	total: 2.57s	remaining: 261ms
# 148:	learn: 0.9586466	test: 0.8091603	best: 0.8461538 (33)	total: 2.59s	remaining: 243ms
# 149:	learn: 0.9586466	test: 0.8091603	best: 0.8461538 (33)	total: 2.6s	remaining: 225ms
# 150:	learn: 0.9566855	test: 0.8091603	best: 0.8461538 (33)	total: 2.62s	remaining: 208ms
# 151:	learn: 0.9566855	test: 0.8091603	best: 0.8461538 (33)	total: 2.63s	remaining: 190ms
# 152:	learn: 0.9566855	test: 0.8091603	best: 0.8461538 (33)	total: 2.64s	remaining: 173ms
# 153:	learn: 0.9604520	test: 0.8091603	best: 0.8461538 (33)	total: 2.65s	remaining: 155ms
# 154:	learn: 0.9662921	test: 0.8000000	best: 0.8461538 (33)	total: 2.67s	remaining: 138ms
# 155:	learn: 0.9662921	test: 0.8091603	best: 0.8461538 (33)	total: 2.68s	remaining: 120ms
# 156:	learn: 0.9662921	test: 0.8000000	best: 0.8461538 (33)	total: 2.7s	remaining: 103ms
# 157:	learn: 0.9662921	test: 0.8091603	best: 0.8461538 (33)	total: 2.71s	remaining: 85.9ms
# 158:	learn: 0.9662921	test: 0.8091603	best: 0.8461538 (33)	total: 2.73s	remaining: 68.7ms
# 159:	learn: 0.9662921	test: 0.8091603	best: 0.8461538 (33)	total: 2.74s	remaining: 51.4ms
# 160:	learn: 0.9662921	test: 0.8091603	best: 0.8461538 (33)	total: 2.75s	remaining: 34.2ms
# 161:	learn: 0.9662921	test: 0.8091603	best: 0.8461538 (33)	total: 2.77s	remaining: 17.1ms
# 162:	learn: 0.9662921	test: 0.8091603	best: 0.8461538 (33)	total: 2.78s	remaining: 0us
#
# bestTest = 0.8461538462
# bestIteration = 33
#
# Training on fold [1/5]
# 0:	learn: 0.7653846	test: 0.7022901	best: 0.7022901 (0)	total: 19.8ms	remaining: 3.2s
# 1:	learn: 0.7868217	test: 0.6821705	best: 0.7022901 (0)	total: 50.7ms	remaining: 4.08s
# 2:	learn: 0.7929688	test: 0.6929134	best: 0.7022901 (0)	total: 68.2ms	remaining: 3.64s
# 3:	learn: 0.7969052	test: 0.6821705	best: 0.7022901 (0)	total: 102ms	remaining: 4.05s
# 4:	learn: 0.8167939	test: 0.6717557	best: 0.7022901 (0)	total: 140ms	remaining: 4.44s
# 5:	learn: 0.8190476	test: 0.6716418	best: 0.7022901 (0)	total: 157ms	remaining: 4.12s
# 6:	learn: 0.8167939	test: 0.6716418	best: 0.7022901 (0)	total: 179ms	remaining: 3.98s
# 7:	learn: 0.8129771	test: 0.6716418	best: 0.7022901 (0)	total: 216ms	remaining: 4.19s
# 8:	learn: 0.8129771	test: 0.6716418	best: 0.7022901 (0)	total: 236ms	remaining: 4.03s
# 9:	learn: 0.8122605	test: 0.6716418	best: 0.7022901 (0)	total: 251ms	remaining: 3.84s
# 10:	learn: 0.8174905	test: 0.6716418	best: 0.7022901 (0)	total: 270ms	remaining: 3.73s
# 11:	learn: 0.8212928	test: 0.7014925	best: 0.7022901 (0)	total: 287ms	remaining: 3.61s
# 12:	learn: 0.8250951	test: 0.7014925	best: 0.7022901 (0)	total: 305ms	remaining: 3.52s
# 13:	learn: 0.8320611	test: 0.6917293	best: 0.7022901 (0)	total: 320ms	remaining: 3.4s
# 14:	learn: 0.8352490	test: 0.6969697	best: 0.7022901 (0)	total: 339ms	remaining: 3.35s
# 15:	learn: 0.8421053	test: 0.6923077	best: 0.7022901 (0)	total: 355ms	remaining: 3.26s
# 16:	learn: 0.8476562	test: 0.6771654	best: 0.7022901 (0)	total: 370ms	remaining: 3.18s
# 17:	learn: 0.8437500	test: 0.6720000	best: 0.7022901 (0)	total: 384ms	remaining: 3.1s
# 18:	learn: 0.8515625	test: 0.6720000	best: 0.7022901 (0)	total: 398ms	remaining: 3.01s
# 19:	learn: 0.8521401	test: 0.6771654	best: 0.7022901 (0)	total: 411ms	remaining: 2.94s
# 20:	learn: 0.8532290	test: 0.6875000	best: 0.7022901 (0)	total: 426ms	remaining: 2.88s
# 21:	learn: 0.8554688	test: 0.6875000	best: 0.7022901 (0)	total: 441ms	remaining: 2.83s
# 22:	learn: 0.8554688	test: 0.6875000	best: 0.7022901 (0)	total: 456ms	remaining: 2.77s
# 23:	learn: 0.8554688	test: 0.6875000	best: 0.7022901 (0)	total: 475ms	remaining: 2.75s
# 24:	learn: 0.8554688	test: 0.6875000	best: 0.7022901 (0)	total: 493ms	remaining: 2.72s
# 25:	learn: 0.8554688	test: 0.6875000	best: 0.7022901 (0)	total: 509ms	remaining: 2.68s
# 26:	learn: 0.8554688	test: 0.6875000	best: 0.7022901 (0)	total: 523ms	remaining: 2.63s
# 27:	learn: 0.8554688	test: 0.6875000	best: 0.7022901 (0)	total: 537ms	remaining: 2.59s
# 28:	learn: 0.8682171	test: 0.6821705	best: 0.7022901 (0)	total: 551ms	remaining: 2.54s
# 29:	learn: 0.8682171	test: 0.6821705	best: 0.7022901 (0)	total: 565ms	remaining: 2.5s
# 30:	learn: 0.8682171	test: 0.6821705	best: 0.7022901 (0)	total: 580ms	remaining: 2.47s
# 31:	learn: 0.8682171	test: 0.6875000	best: 0.7022901 (0)	total: 592ms	remaining: 2.42s
# 32:	learn: 0.8682171	test: 0.6821705	best: 0.7022901 (0)	total: 605ms	remaining: 2.38s
# 33:	learn: 0.8704062	test: 0.6875000	best: 0.7022901 (0)	total: 618ms	remaining: 2.35s
# 34:	learn: 0.8742747	test: 0.6771654	best: 0.7022901 (0)	total: 635ms	remaining: 2.32s
# 35:	learn: 0.8742747	test: 0.6771654	best: 0.7022901 (0)	total: 648ms	remaining: 2.29s
# 36:	learn: 0.8742747	test: 0.6771654	best: 0.7022901 (0)	total: 662ms	remaining: 2.25s
# 37:	learn: 0.8786127	test: 0.6771654	best: 0.7022901 (0)	total: 678ms	remaining: 2.23s
# 38:	learn: 0.8769231	test: 0.6825397	best: 0.7022901 (0)	total: 694ms	remaining: 2.21s
# 39:	learn: 0.8769231	test: 0.6825397	best: 0.7022901 (0)	total: 709ms	remaining: 2.18s
# 40:	learn: 0.8790787	test: 0.6825397	best: 0.7022901 (0)	total: 723ms	remaining: 2.15s
# 41:	learn: 0.8769231	test: 0.6825397	best: 0.7022901 (0)	total: 736ms	remaining: 2.12s
# 42:	learn: 0.8884615	test: 0.6720000	best: 0.7022901 (0)	total: 753ms	remaining: 2.1s
# 43:	learn: 0.8923077	test: 0.6771654	best: 0.7022901 (0)	total: 765ms	remaining: 2.07s
# 44:	learn: 0.8940270	test: 0.6771654	best: 0.7022901 (0)	total: 780ms	remaining: 2.05s
# 45:	learn: 0.9034749	test: 0.6771654	best: 0.7022901 (0)	total: 793ms	remaining: 2.02s
# 46:	learn: 0.8996139	test: 0.6771654	best: 0.7022901 (0)	total: 806ms	remaining: 1.99s
# 47:	learn: 0.9013540	test: 0.6666667	best: 0.7022901 (0)	total: 820ms	remaining: 1.96s
# 48:	learn: 0.9069767	test: 0.6771654	best: 0.7022901 (0)	total: 832ms	remaining: 1.93s
# 49:	learn: 0.9031008	test: 0.6666667	best: 0.7022901 (0)	total: 850ms	remaining: 1.92s
# 50:	learn: 0.9031008	test: 0.6666667	best: 0.7022901 (0)	total: 862ms	remaining: 1.89s
# 51:	learn: 0.9031008	test: 0.6666667	best: 0.7022901 (0)	total: 875ms	remaining: 1.87s
# 52:	learn: 0.9013540	test: 0.6666667	best: 0.7022901 (0)	total: 891ms	remaining: 1.85s
# 53:	learn: 0.9052224	test: 0.6771654	best: 0.7022901 (0)	total: 911ms	remaining: 1.84s
# 54:	learn: 0.9090909	test: 0.6771654	best: 0.7022901 (0)	total: 929ms	remaining: 1.82s
# 55:	learn: 0.9090909	test: 0.6771654	best: 0.7022901 (0)	total: 948ms	remaining: 1.81s
# 56:	learn: 0.9111969	test: 0.6771654	best: 0.7022901 (0)	total: 969ms	remaining: 1.8s
# 57:	learn: 0.9153846	test: 0.6718750	best: 0.7022901 (0)	total: 1s	remaining: 1.82s
# 58:	learn: 0.9153846	test: 0.6771654	best: 0.7022901 (0)	total: 1.02s	remaining: 1.8s
# 59:	learn: 0.9174664	test: 0.6771654	best: 0.7022901 (0)	total: 1.05s	remaining: 1.8s
# 60:	learn: 0.9174664	test: 0.6718750	best: 0.7022901 (0)	total: 1.07s	remaining: 1.79s
# 61:	learn: 0.9174664	test: 0.6718750	best: 0.7022901 (0)	total: 1.09s	remaining: 1.78s
# 62:	learn: 0.9174664	test: 0.6718750	best: 0.7022901 (0)	total: 1.12s	remaining: 1.77s
# 63:	learn: 0.9174664	test: 0.6718750	best: 0.7022901 (0)	total: 1.13s	remaining: 1.75s
# 64:	learn: 0.9174664	test: 0.6666667	best: 0.7022901 (0)	total: 1.15s	remaining: 1.73s
# 65:	learn: 0.9192308	test: 0.6718750	best: 0.7022901 (0)	total: 1.16s	remaining: 1.71s
# 66:	learn: 0.9210019	test: 0.6666667	best: 0.7022901 (0)	total: 1.18s	remaining: 1.69s
# 67:	learn: 0.9210019	test: 0.6666667	best: 0.7022901 (0)	total: 1.2s	remaining: 1.68s
# 68:	learn: 0.9210019	test: 0.6718750	best: 0.7022901 (0)	total: 1.22s	remaining: 1.66s
# 69:	learn: 0.9227799	test: 0.6718750	best: 0.7022901 (0)	total: 1.23s	remaining: 1.63s
# 70:	learn: 0.9227799	test: 0.6666667	best: 0.7022901 (0)	total: 1.25s	remaining: 1.61s
# 71:	learn: 0.9269231	test: 0.6666667	best: 0.7022901 (0)	total: 1.26s	remaining: 1.59s
# 72:	learn: 0.9269231	test: 0.6718750	best: 0.7022901 (0)	total: 1.27s	remaining: 1.57s
# 73:	learn: 0.9269231	test: 0.6718750	best: 0.7022901 (0)	total: 1.29s	remaining: 1.55s
# 74:	learn: 0.9289827	test: 0.6718750	best: 0.7022901 (0)	total: 1.3s	remaining: 1.53s
# 75:	learn: 0.9310345	test: 0.6718750	best: 0.7022901 (0)	total: 1.32s	remaining: 1.51s
# 76:	learn: 0.9330784	test: 0.6821705	best: 0.7022901 (0)	total: 1.34s	remaining: 1.49s
# 77:	learn: 0.9289827	test: 0.6718750	best: 0.7022901 (0)	total: 1.35s	remaining: 1.47s
# 78:	learn: 0.9348659	test: 0.6614173	best: 0.7022901 (0)	total: 1.36s	remaining: 1.45s
# 79:	learn: 0.9348659	test: 0.6718750	best: 0.7022901 (0)	total: 1.38s	remaining: 1.43s
# 80:	learn: 0.9348659	test: 0.6718750	best: 0.7022901 (0)	total: 1.4s	remaining: 1.42s
# 81:	learn: 0.9348659	test: 0.6666667	best: 0.7022901 (0)	total: 1.42s	remaining: 1.4s
# 82:	learn: 0.9369025	test: 0.6666667	best: 0.7022901 (0)	total: 1.44s	remaining: 1.39s
# 83:	learn: 0.9389313	test: 0.6666667	best: 0.7022901 (0)	total: 1.47s	remaining: 1.38s
# 84:	learn: 0.9407266	test: 0.6666667	best: 0.7022901 (0)	total: 1.49s	remaining: 1.36s
# 85:	learn: 0.9389313	test: 0.6564885	best: 0.7022901 (0)	total: 1.5s	remaining: 1.35s
# 86:	learn: 0.9389313	test: 0.6564885	best: 0.7022901 (0)	total: 1.52s	remaining: 1.33s
# 87:	learn: 0.9389313	test: 0.6564885	best: 0.7022901 (0)	total: 1.54s	remaining: 1.31s
# 88:	learn: 0.9389313	test: 0.6564885	best: 0.7022901 (0)	total: 1.56s	remaining: 1.3s
# 89:	learn: 0.9427481	test: 0.6615385	best: 0.7022901 (0)	total: 1.58s	remaining: 1.28s
# 90:	learn: 0.9389313	test: 0.6666667	best: 0.7022901 (0)	total: 1.6s	remaining: 1.26s
# 91:	learn: 0.9407266	test: 0.6562500	best: 0.7022901 (0)	total: 1.61s	remaining: 1.25s
# 92:	learn: 0.9427481	test: 0.6562500	best: 0.7022901 (0)	total: 1.63s	remaining: 1.23s
# 93:	learn: 0.9467681	test: 0.6511628	best: 0.7022901 (0)	total: 1.65s	remaining: 1.21s
# 94:	learn: 0.9467681	test: 0.6614173	best: 0.7022901 (0)	total: 1.67s	remaining: 1.2s
# 95:	learn: 0.9487666	test: 0.6614173	best: 0.7022901 (0)	total: 1.7s	remaining: 1.18s
# 96:	learn: 0.9487666	test: 0.6562500	best: 0.7022901 (0)	total: 1.72s	remaining: 1.17s
# 97:	learn: 0.9487666	test: 0.6511628	best: 0.7022901 (0)	total: 1.73s	remaining: 1.15s
# 98:	learn: 0.9487666	test: 0.6511628	best: 0.7022901 (0)	total: 1.76s	remaining: 1.14s
# 99:	learn: 0.9487666	test: 0.6511628	best: 0.7022901 (0)	total: 1.78s	remaining: 1.12s
# 100:	learn: 0.9469697	test: 0.6511628	best: 0.7022901 (0)	total: 1.8s	remaining: 1.11s
# 101:	learn: 0.9487666	test: 0.6562500	best: 0.7022901 (0)	total: 1.82s	remaining: 1.09s
# 102:	learn: 0.9487666	test: 0.6562500	best: 0.7022901 (0)	total: 1.84s	remaining: 1.07s
# 103:	learn: 0.9487666	test: 0.6562500	best: 0.7022901 (0)	total: 1.87s	remaining: 1.06s
# 104:	learn: 0.9487666	test: 0.6511628	best: 0.7022901 (0)	total: 1.89s	remaining: 1.04s
# 105:	learn: 0.9487666	test: 0.6615385	best: 0.7022901 (0)	total: 1.9s	remaining: 1.02s
# 106:	learn: 0.9507576	test: 0.6615385	best: 0.7022901 (0)	total: 1.92s	remaining: 1.01s
# 107:	learn: 0.9507576	test: 0.6564885	best: 0.7022901 (0)	total: 1.94s	remaining: 988ms
# 108:	learn: 0.9507576	test: 0.6564885	best: 0.7022901 (0)	total: 1.96s	remaining: 971ms
# 109:	learn: 0.9507576	test: 0.6564885	best: 0.7022901 (0)	total: 1.98s	remaining: 954ms
# 110:	learn: 0.9507576	test: 0.6461538	best: 0.7022901 (0)	total: 2s	remaining: 935ms
# 111:	learn: 0.9507576	test: 0.6461538	best: 0.7022901 (0)	total: 2.01s	remaining: 916ms
# 112:	learn: 0.9527410	test: 0.6461538	best: 0.7022901 (0)	total: 2.03s	remaining: 897ms
# 113:	learn: 0.9547170	test: 0.6511628	best: 0.7022901 (0)	total: 2.04s	remaining: 879ms
# 114:	learn: 0.9547170	test: 0.6511628	best: 0.7022901 (0)	total: 2.06s	remaining: 859ms
# 115:	learn: 0.9547170	test: 0.6511628	best: 0.7022901 (0)	total: 2.07s	remaining: 839ms
# 116:	learn: 0.9547170	test: 0.6511628	best: 0.7022901 (0)	total: 2.08s	remaining: 820ms
# 117:	learn: 0.9547170	test: 0.6511628	best: 0.7022901 (0)	total: 2.1s	remaining: 800ms
# 118:	learn: 0.9547170	test: 0.6615385	best: 0.7022901 (0)	total: 2.11s	remaining: 782ms
# 119:	learn: 0.9547170	test: 0.6564885	best: 0.7022901 (0)	total: 2.13s	remaining: 764ms
# 120:	learn: 0.9547170	test: 0.6564885	best: 0.7022901 (0)	total: 2.14s	remaining: 744ms
# 121:	learn: 0.9547170	test: 0.6461538	best: 0.7022901 (0)	total: 2.17s	remaining: 729ms
# 122:	learn: 0.9547170	test: 0.6461538	best: 0.7022901 (0)	total: 2.19s	remaining: 713ms
# 123:	learn: 0.9547170	test: 0.6461538	best: 0.7022901 (0)	total: 2.22s	remaining: 698ms
# 124:	learn: 0.9547170	test: 0.6461538	best: 0.7022901 (0)	total: 2.23s	remaining: 679ms
# 125:	learn: 0.9547170	test: 0.6461538	best: 0.7022901 (0)	total: 2.25s	remaining: 660ms
# 126:	learn: 0.9547170	test: 0.6511628	best: 0.7022901 (0)	total: 2.26s	remaining: 642ms
# 127:	learn: 0.9547170	test: 0.6615385	best: 0.7022901 (0)	total: 2.28s	remaining: 624ms
# 128:	learn: 0.9547170	test: 0.6615385	best: 0.7022901 (0)	total: 2.3s	remaining: 606ms
# 129:	learn: 0.9547170	test: 0.6615385	best: 0.7022901 (0)	total: 2.31s	remaining: 587ms
# 130:	learn: 0.9566855	test: 0.6615385	best: 0.7022901 (0)	total: 2.32s	remaining: 568ms
# 131:	learn: 0.9566855	test: 0.6615385	best: 0.7022901 (0)	total: 2.34s	remaining: 549ms
# 132:	learn: 0.9566855	test: 0.6511628	best: 0.7022901 (0)	total: 2.35s	remaining: 530ms
# 133:	learn: 0.9586466	test: 0.6615385	best: 0.7022901 (0)	total: 2.36s	remaining: 511ms
# 134:	learn: 0.9586466	test: 0.6615385	best: 0.7022901 (0)	total: 2.37s	remaining: 492ms
# 135:	learn: 0.9606004	test: 0.6615385	best: 0.7022901 (0)	total: 2.39s	remaining: 474ms
# 136:	learn: 0.9606004	test: 0.6666667	best: 0.7022901 (0)	total: 2.4s	remaining: 456ms
# 137:	learn: 0.9606004	test: 0.6666667	best: 0.7022901 (0)	total: 2.42s	remaining: 439ms
# 138:	learn: 0.9625468	test: 0.6666667	best: 0.7022901 (0)	total: 2.44s	remaining: 421ms
# 139:	learn: 0.9643527	test: 0.6718750	best: 0.7022901 (0)	total: 2.45s	remaining: 403ms
# 140:	learn: 0.9662921	test: 0.6718750	best: 0.7022901 (0)	total: 2.47s	remaining: 386ms
# 141:	learn: 0.9662921	test: 0.6718750	best: 0.7022901 (0)	total: 2.49s	remaining: 368ms
# 142:	learn: 0.9643527	test: 0.6718750	best: 0.7022901 (0)	total: 2.5s	remaining: 350ms
# 143:	learn: 0.9643527	test: 0.6666667	best: 0.7022901 (0)	total: 2.52s	remaining: 332ms
# 144:	learn: 0.9643527	test: 0.6666667	best: 0.7022901 (0)	total: 2.53s	remaining: 315ms
# 145:	learn: 0.9643527	test: 0.6666667	best: 0.7022901 (0)	total: 2.55s	remaining: 297ms
# 146:	learn: 0.9643527	test: 0.6666667	best: 0.7022901 (0)	total: 2.57s	remaining: 280ms
# 147:	learn: 0.9644860	test: 0.6666667	best: 0.7022901 (0)	total: 2.59s	remaining: 262ms
# 148:	learn: 0.9662921	test: 0.6718750	best: 0.7022901 (0)	total: 2.6s	remaining: 244ms
# 149:	learn: 0.9644860	test: 0.6718750	best: 0.7022901 (0)	total: 2.62s	remaining: 227ms
# 150:	learn: 0.9644860	test: 0.6666667	best: 0.7022901 (0)	total: 2.63s	remaining: 209ms
# 151:	learn: 0.9682243	test: 0.6615385	best: 0.7022901 (0)	total: 2.65s	remaining: 192ms
# 152:	learn: 0.9682243	test: 0.6666667	best: 0.7022901 (0)	total: 2.67s	remaining: 174ms
# 153:	learn: 0.9682243	test: 0.6666667	best: 0.7022901 (0)	total: 2.68s	remaining: 157ms
# 154:	learn: 0.9700375	test: 0.6666667	best: 0.7022901 (0)	total: 2.7s	remaining: 139ms
# 155:	learn: 0.9700375	test: 0.6615385	best: 0.7022901 (0)	total: 2.72s	remaining: 122ms
# 156:	learn: 0.9700375	test: 0.6615385	best: 0.7022901 (0)	total: 2.74s	remaining: 105ms
# 157:	learn: 0.9700375	test: 0.6718750	best: 0.7022901 (0)	total: 2.75s	remaining: 87.1ms
# 158:	learn: 0.9700375	test: 0.6718750	best: 0.7022901 (0)	total: 2.76s	remaining: 69.5ms
# 159:	learn: 0.9700375	test: 0.6718750	best: 0.7022901 (0)	total: 2.78s	remaining: 52.2ms
# 160:	learn: 0.9700375	test: 0.6666667	best: 0.7022901 (0)	total: 2.8s	remaining: 34.8ms
# 161:	learn: 0.9700375	test: 0.6666667	best: 0.7022901 (0)	total: 2.83s	remaining: 17.5ms
# 162:	learn: 0.9700375	test: 0.6666667	best: 0.7022901 (0)	total: 2.86s	remaining: 0us
#
# bestTest = 0.7022900763
# bestIteration = 0
#
# Training on fold [2/5]
# 0:	learn: 0.7639155	test: 0.6969697	best: 0.6969697 (0)	total: 11.8ms	remaining: 1.91s
# 1:	learn: 0.7715931	test: 0.6717557	best: 0.6969697 (0)	total: 27.3ms	remaining: 2.2s
# 2:	learn: 0.7707129	test: 0.6821705	best: 0.6969697 (0)	total: 37.2ms	remaining: 1.98s
# 3:	learn: 0.7730769	test: 0.6821705	best: 0.6969697 (0)	total: 53.1ms	remaining: 2.11s
# 4:	learn: 0.7844660	test: 0.6829268	best: 0.6969697 (0)	total: 66.9ms	remaining: 2.11s
# 5:	learn: 0.7844660	test: 0.6829268	best: 0.6969697 (0)	total: 87ms	remaining: 2.28s
# 6:	learn: 0.7852998	test: 0.6829268	best: 0.6969697 (0)	total: 100ms	remaining: 2.23s
# 7:	learn: 0.7868217	test: 0.6829268	best: 0.6969697 (0)	total: 115ms	remaining: 2.23s
# 8:	learn: 0.7868217	test: 0.6829268	best: 0.6969697 (0)	total: 129ms	remaining: 2.2s
# 9:	learn: 0.7944664	test: 0.6890756	best: 0.6969697 (0)	total: 143ms	remaining: 2.19s
# 10:	learn: 0.8183633	test: 0.7008547	best: 0.7008547 (10)	total: 158ms	remaining: 2.19s
# 11:	learn: 0.8198020	test: 0.7166667	best: 0.7166667 (11)	total: 171ms	remaining: 2.15s
# 12:	learn: 0.8190855	test: 0.7226891	best: 0.7226891 (12)	total: 183ms	remaining: 2.11s
# 13:	learn: 0.8228346	test: 0.7226891	best: 0.7226891 (12)	total: 201ms	remaining: 2.14s
# 14:	learn: 0.8297456	test: 0.7272727	best: 0.7272727 (14)	total: 218ms	remaining: 2.15s
# 15:	learn: 0.8443580	test: 0.7272727	best: 0.7272727 (14)	total: 231ms	remaining: 2.13s
# 16:	learn: 0.8571429	test: 0.7107438	best: 0.7272727 (14)	total: 244ms	remaining: 2.1s
# 17:	learn: 0.8598848	test: 0.7154472	best: 0.7272727 (14)	total: 257ms	remaining: 2.07s
# 18:	learn: 0.8582524	test: 0.7096774	best: 0.7272727 (14)	total: 269ms	remaining: 2.04s
# 19:	learn: 0.8571429	test: 0.7049180	best: 0.7272727 (14)	total: 289ms	remaining: 2.07s
# 20:	learn: 0.8532819	test: 0.7154472	best: 0.7272727 (14)	total: 303ms	remaining: 2.04s
# 21:	learn: 0.8576923	test: 0.7107438	best: 0.7272727 (14)	total: 315ms	remaining: 2.02s
# 22:	learn: 0.8615385	test: 0.7040000	best: 0.7272727 (14)	total: 330ms	remaining: 2.01s
# 23:	learn: 0.8615385	test: 0.7142857	best: 0.7272727 (14)	total: 348ms	remaining: 2.02s
# 24:	learn: 0.8598848	test: 0.7096774	best: 0.7272727 (14)	total: 361ms	remaining: 2s
# 25:	learn: 0.8593156	test: 0.7154472	best: 0.7272727 (14)	total: 377ms	remaining: 1.98s
# 26:	learn: 0.8571429	test: 0.7154472	best: 0.7272727 (14)	total: 395ms	remaining: 1.99s
# 27:	learn: 0.8609524	test: 0.7096774	best: 0.7272727 (14)	total: 409ms	remaining: 1.97s
# 28:	learn: 0.8625954	test: 0.7096774	best: 0.7272727 (14)	total: 425ms	remaining: 1.96s
# 29:	learn: 0.8631179	test: 0.7154472	best: 0.7272727 (14)	total: 439ms	remaining: 1.95s
# 30:	learn: 0.8647619	test: 0.7040000	best: 0.7272727 (14)	total: 457ms	remaining: 1.94s
# 31:	learn: 0.8690702	test: 0.7040000	best: 0.7272727 (14)	total: 471ms	remaining: 1.93s
# 32:	learn: 0.8690702	test: 0.7040000	best: 0.7272727 (14)	total: 488ms	remaining: 1.92s
# 33:	learn: 0.8728653	test: 0.7142857	best: 0.7272727 (14)	total: 502ms	remaining: 1.9s
# 34:	learn: 0.8690702	test: 0.7142857	best: 0.7272727 (14)	total: 521ms	remaining: 1.91s
# 35:	learn: 0.8680688	test: 0.7040000	best: 0.7272727 (14)	total: 538ms	remaining: 1.9s
# 36:	learn: 0.8702290	test: 0.7040000	best: 0.7272727 (14)	total: 555ms	remaining: 1.89s
# 37:	learn: 0.8702290	test: 0.7142857	best: 0.7272727 (14)	total: 568ms	remaining: 1.87s
# 38:	learn: 0.8702290	test: 0.7301587	best: 0.7301587 (38)	total: 580ms	remaining: 1.84s
# 39:	learn: 0.8740458	test: 0.7301587	best: 0.7301587 (38)	total: 593ms	remaining: 1.82s
# 40:	learn: 0.8761905	test: 0.7301587	best: 0.7301587 (38)	total: 605ms	remaining: 1.8s
# 41:	learn: 0.8761905	test: 0.7301587	best: 0.7301587 (38)	total: 622ms	remaining: 1.79s
# 42:	learn: 0.8761905	test: 0.7360000	best: 0.7360000 (42)	total: 635ms	remaining: 1.77s
# 43:	learn: 0.8783270	test: 0.7401575	best: 0.7401575 (43)	total: 647ms	remaining: 1.75s
# 44:	learn: 0.8783270	test: 0.7343750	best: 0.7401575 (43)	total: 661ms	remaining: 1.73s
# 45:	learn: 0.8761905	test: 0.7244094	best: 0.7401575 (43)	total: 679ms	remaining: 1.73s
# 46:	learn: 0.8783270	test: 0.7301587	best: 0.7401575 (43)	total: 691ms	remaining: 1.71s
# 47:	learn: 0.8761905	test: 0.7301587	best: 0.7401575 (43)	total: 706ms	remaining: 1.69s
# 48:	learn: 0.8761905	test: 0.7301587	best: 0.7401575 (43)	total: 720ms	remaining: 1.68s
# 49:	learn: 0.8783270	test: 0.7200000	best: 0.7401575 (43)	total: 739ms	remaining: 1.67s
# 50:	learn: 0.8783270	test: 0.7301587	best: 0.7401575 (43)	total: 754ms	remaining: 1.66s
# 51:	learn: 0.8761905	test: 0.7301587	best: 0.7401575 (43)	total: 768ms	remaining: 1.64s
# 52:	learn: 0.8761905	test: 0.7301587	best: 0.7401575 (43)	total: 783ms	remaining: 1.63s
# 53:	learn: 0.8816794	test: 0.7301587	best: 0.7401575 (43)	total: 796ms	remaining: 1.61s
# 54:	learn: 0.8816794	test: 0.7301587	best: 0.7401575 (43)	total: 809ms	remaining: 1.59s
# 55:	learn: 0.8816794	test: 0.7301587	best: 0.7401575 (43)	total: 822ms	remaining: 1.57s
# 56:	learn: 0.8816794	test: 0.7301587	best: 0.7401575 (43)	total: 835ms	remaining: 1.55s
# 57:	learn: 0.8833652	test: 0.7419355	best: 0.7419355 (57)	total: 848ms	remaining: 1.53s
# 58:	learn: 0.8795411	test: 0.7360000	best: 0.7419355 (57)	total: 863ms	remaining: 1.52s
# 59:	learn: 0.8816794	test: 0.7360000	best: 0.7419355 (57)	total: 878ms	remaining: 1.51s
# 60:	learn: 0.8838095	test: 0.7360000	best: 0.7419355 (57)	total: 889ms	remaining: 1.49s
# 61:	learn: 0.8821293	test: 0.7360000	best: 0.7419355 (57)	total: 902ms	remaining: 1.47s
# 62:	learn: 0.8854962	test: 0.7360000	best: 0.7419355 (57)	total: 914ms	remaining: 1.45s
# 63:	learn: 0.8876190	test: 0.7360000	best: 0.7419355 (57)	total: 930ms	remaining: 1.44s
# 64:	learn: 0.8939394	test: 0.7360000	best: 0.7419355 (57)	total: 1000ms	remaining: 1.51s
# 65:	learn: 0.8973384	test: 0.7360000	best: 0.7419355 (57)	total: 1.04s	remaining: 1.52s
# 66:	learn: 0.8973384	test: 0.7360000	best: 0.7419355 (57)	total: 1.06s	remaining: 1.52s
# 67:	learn: 0.8973384	test: 0.7360000	best: 0.7419355 (57)	total: 1.1s	remaining: 1.53s
# 68:	learn: 0.8994307	test: 0.7360000	best: 0.7419355 (57)	total: 1.12s	remaining: 1.53s
# 69:	learn: 0.9015152	test: 0.7360000	best: 0.7419355 (57)	total: 1.16s	remaining: 1.54s
# 70:	learn: 0.9032258	test: 0.7360000	best: 0.7419355 (57)	total: 1.17s	remaining: 1.52s
# 71:	learn: 0.9032258	test: 0.7559055	best: 0.7559055 (71)	total: 1.18s	remaining: 1.5s
# 72:	learn: 0.9049430	test: 0.7656250	best: 0.7656250 (72)	total: 1.2s	remaining: 1.48s
# 73:	learn: 0.9070209	test: 0.7559055	best: 0.7656250 (72)	total: 1.22s	remaining: 1.47s
# 74:	learn: 0.9104762	test: 0.7360000	best: 0.7656250 (72)	total: 1.24s	remaining: 1.45s
# 75:	learn: 0.9104762	test: 0.7460317	best: 0.7656250 (72)	total: 1.25s	remaining: 1.43s
# 76:	learn: 0.9125475	test: 0.7460317	best: 0.7656250 (72)	total: 1.26s	remaining: 1.41s
# 77:	learn: 0.9125475	test: 0.7559055	best: 0.7656250 (72)	total: 1.28s	remaining: 1.4s
# 78:	learn: 0.9125475	test: 0.7559055	best: 0.7656250 (72)	total: 1.3s	remaining: 1.38s
# 79:	learn: 0.9160305	test: 0.7460317	best: 0.7656250 (72)	total: 1.31s	remaining: 1.36s
# 80:	learn: 0.9142857	test: 0.7559055	best: 0.7656250 (72)	total: 1.33s	remaining: 1.35s
# 81:	learn: 0.9142857	test: 0.7559055	best: 0.7656250 (72)	total: 1.35s	remaining: 1.33s
# 82:	learn: 0.9142857	test: 0.7460317	best: 0.7656250 (72)	total: 1.39s	remaining: 1.33s
# 83:	learn: 0.9142857	test: 0.7460317	best: 0.7656250 (72)	total: 1.42s	remaining: 1.33s
# 84:	learn: 0.9163498	test: 0.7460317	best: 0.7656250 (72)	total: 1.45s	remaining: 1.33s
# 85:	learn: 0.9142857	test: 0.7520000	best: 0.7656250 (72)	total: 1.47s	remaining: 1.31s
# 86:	learn: 0.9184061	test: 0.7460317	best: 0.7656250 (72)	total: 1.49s	remaining: 1.3s
# 87:	learn: 0.9201521	test: 0.7460317	best: 0.7656250 (72)	total: 1.5s	remaining: 1.28s
# 88:	learn: 0.9280303	test: 0.7460317	best: 0.7656250 (72)	total: 1.52s	remaining: 1.27s
# 89:	learn: 0.9283019	test: 0.7460317	best: 0.7656250 (72)	total: 1.54s	remaining: 1.25s
# 90:	learn: 0.9283019	test: 0.7460317	best: 0.7656250 (72)	total: 1.56s	remaining: 1.23s
# 91:	learn: 0.9283019	test: 0.7460317	best: 0.7656250 (72)	total: 1.57s	remaining: 1.21s
# 92:	learn: 0.9318182	test: 0.7460317	best: 0.7656250 (72)	total: 1.58s	remaining: 1.19s
# 93:	learn: 0.9283019	test: 0.7401575	best: 0.7656250 (72)	total: 1.6s	remaining: 1.17s
# 94:	learn: 0.9335863	test: 0.7401575	best: 0.7656250 (72)	total: 1.61s	remaining: 1.15s
# 95:	learn: 0.9335863	test: 0.7401575	best: 0.7656250 (72)	total: 1.63s	remaining: 1.13s
# 96:	learn: 0.9335863	test: 0.7301587	best: 0.7656250 (72)	total: 1.64s	remaining: 1.12s
# 97:	learn: 0.9318182	test: 0.7301587	best: 0.7656250 (72)	total: 1.66s	remaining: 1.1s
# 98:	learn: 0.9318182	test: 0.7244094	best: 0.7656250 (72)	total: 1.68s	remaining: 1.08s
# 99:	learn: 0.9335863	test: 0.7244094	best: 0.7656250 (72)	total: 1.7s	remaining: 1.07s
# 100:	learn: 0.9356061	test: 0.7187500	best: 0.7656250 (72)	total: 1.71s	remaining: 1.05s
# 101:	learn: 0.9376181	test: 0.7244094	best: 0.7656250 (72)	total: 1.73s	remaining: 1.03s
# 102:	learn: 0.9396226	test: 0.7244094	best: 0.7656250 (72)	total: 1.75s	remaining: 1.02s
# 103:	learn: 0.9396226	test: 0.7343750	best: 0.7656250 (72)	total: 1.77s	remaining: 1s
# 104:	learn: 0.9396226	test: 0.7286822	best: 0.7656250 (72)	total: 1.79s	remaining: 990ms
# 105:	learn: 0.9396226	test: 0.7286822	best: 0.7656250 (72)	total: 1.81s	remaining: 974ms
# 106:	learn: 0.9396226	test: 0.7343750	best: 0.7656250 (72)	total: 1.84s	remaining: 962ms
# 107:	learn: 0.9396226	test: 0.7343750	best: 0.7656250 (72)	total: 1.86s	remaining: 947ms
# 108:	learn: 0.9396226	test: 0.7343750	best: 0.7656250 (72)	total: 1.87s	remaining: 929ms
# 109:	learn: 0.9396226	test: 0.7441860	best: 0.7656250 (72)	total: 1.89s	remaining: 910ms
# 110:	learn: 0.9396226	test: 0.7441860	best: 0.7656250 (72)	total: 1.9s	remaining: 892ms
# 111:	learn: 0.9396226	test: 0.7441860	best: 0.7656250 (72)	total: 1.92s	remaining: 875ms
# 112:	learn: 0.9416196	test: 0.7384615	best: 0.7656250 (72)	total: 1.93s	remaining: 856ms
# 113:	learn: 0.9416196	test: 0.7384615	best: 0.7656250 (72)	total: 1.95s	remaining: 839ms
# 114:	learn: 0.9416196	test: 0.7384615	best: 0.7656250 (72)	total: 1.98s	remaining: 825ms
# 115:	learn: 0.9436090	test: 0.7441860	best: 0.7656250 (72)	total: 2s	remaining: 810ms
# 116:	learn: 0.9436090	test: 0.7500000	best: 0.7656250 (72)	total: 2.02s	remaining: 793ms
# 117:	learn: 0.9436090	test: 0.7441860	best: 0.7656250 (72)	total: 2.03s	remaining: 776ms
# 118:	learn: 0.9436090	test: 0.7401575	best: 0.7656250 (72)	total: 2.06s	remaining: 762ms
# 119:	learn: 0.9475655	test: 0.7401575	best: 0.7656250 (72)	total: 2.08s	remaining: 746ms
# 120:	learn: 0.9475655	test: 0.7401575	best: 0.7656250 (72)	total: 2.1s	remaining: 730ms
# 121:	learn: 0.9495327	test: 0.7401575	best: 0.7656250 (72)	total: 2.18s	remaining: 734ms
# 122:	learn: 0.9495327	test: 0.7401575	best: 0.7656250 (72)	total: 2.23s	remaining: 725ms
# 123:	learn: 0.9495327	test: 0.7401575	best: 0.7656250 (72)	total: 2.25s	remaining: 707ms
# 124:	learn: 0.9514925	test: 0.7401575	best: 0.7656250 (72)	total: 2.26s	remaining: 687ms
# 125:	learn: 0.9514925	test: 0.7401575	best: 0.7656250 (72)	total: 2.28s	remaining: 670ms
# 126:	learn: 0.9532710	test: 0.7401575	best: 0.7656250 (72)	total: 2.3s	remaining: 652ms
# 127:	learn: 0.9513109	test: 0.7401575	best: 0.7656250 (72)	total: 2.31s	remaining: 633ms
# 128:	learn: 0.9513109	test: 0.7460317	best: 0.7656250 (72)	total: 2.33s	remaining: 615ms
# 129:	learn: 0.9493433	test: 0.7460317	best: 0.7656250 (72)	total: 2.35s	remaining: 596ms
# 130:	learn: 0.9532710	test: 0.7460317	best: 0.7656250 (72)	total: 2.36s	remaining: 577ms
# 131:	learn: 0.9532710	test: 0.7460317	best: 0.7656250 (72)	total: 2.38s	remaining: 558ms
# 132:	learn: 0.9532710	test: 0.7460317	best: 0.7656250 (72)	total: 2.39s	remaining: 540ms
# 133:	learn: 0.9513109	test: 0.7460317	best: 0.7656250 (72)	total: 2.41s	remaining: 521ms
# 134:	learn: 0.9513109	test: 0.7401575	best: 0.7656250 (72)	total: 2.42s	remaining: 502ms
# 135:	learn: 0.9513109	test: 0.7460317	best: 0.7656250 (72)	total: 2.44s	remaining: 484ms
# 136:	learn: 0.9513109	test: 0.7460317	best: 0.7656250 (72)	total: 2.45s	remaining: 465ms
# 137:	learn: 0.9513109	test: 0.7460317	best: 0.7656250 (72)	total: 2.46s	remaining: 446ms
# 138:	learn: 0.9513109	test: 0.7401575	best: 0.7656250 (72)	total: 2.48s	remaining: 428ms
# 139:	learn: 0.9513109	test: 0.7401575	best: 0.7656250 (72)	total: 2.49s	remaining: 410ms
# 140:	learn: 0.9513109	test: 0.7401575	best: 0.7656250 (72)	total: 2.51s	remaining: 392ms
# 141:	learn: 0.9530957	test: 0.7401575	best: 0.7656250 (72)	total: 2.52s	remaining: 373ms
# 142:	learn: 0.9530957	test: 0.7401575	best: 0.7656250 (72)	total: 2.54s	remaining: 355ms
# 143:	learn: 0.9530957	test: 0.7401575	best: 0.7656250 (72)	total: 2.55s	remaining: 336ms
# 144:	learn: 0.9530957	test: 0.7401575	best: 0.7656250 (72)	total: 2.56s	remaining: 318ms
# 145:	learn: 0.9530957	test: 0.7401575	best: 0.7656250 (72)	total: 2.58s	remaining: 301ms
# 146:	learn: 0.9530957	test: 0.7401575	best: 0.7656250 (72)	total: 2.6s	remaining: 283ms
# 147:	learn: 0.9530957	test: 0.7401575	best: 0.7656250 (72)	total: 2.61s	remaining: 265ms
# 148:	learn: 0.9530957	test: 0.7401575	best: 0.7656250 (72)	total: 2.62s	remaining: 247ms
# 149:	learn: 0.9550562	test: 0.7401575	best: 0.7656250 (72)	total: 2.64s	remaining: 229ms
# 150:	learn: 0.9568480	test: 0.7401575	best: 0.7656250 (72)	total: 2.65s	remaining: 211ms
# 151:	learn: 0.9588015	test: 0.7401575	best: 0.7656250 (72)	total: 2.67s	remaining: 193ms
# 152:	learn: 0.9588015	test: 0.7401575	best: 0.7656250 (72)	total: 2.68s	remaining: 175ms
# 153:	learn: 0.9588015	test: 0.7520000	best: 0.7656250 (72)	total: 2.69s	remaining: 158ms
# 154:	learn: 0.9568480	test: 0.7520000	best: 0.7656250 (72)	total: 2.71s	remaining: 140ms
# 155:	learn: 0.9588015	test: 0.7520000	best: 0.7656250 (72)	total: 2.73s	remaining: 122ms
# 156:	learn: 0.9568480	test: 0.7520000	best: 0.7656250 (72)	total: 2.74s	remaining: 105ms
# 157:	learn: 0.9568480	test: 0.7520000	best: 0.7656250 (72)	total: 2.75s	remaining: 87.1ms
# 158:	learn: 0.9568480	test: 0.7460317	best: 0.7656250 (72)	total: 2.77s	remaining: 69.7ms
# 159:	learn: 0.9588015	test: 0.7460317	best: 0.7656250 (72)	total: 2.79s	remaining: 52.3ms
# 160:	learn: 0.9588015	test: 0.7360000	best: 0.7656250 (72)	total: 2.8s	remaining: 34.8ms
# 161:	learn: 0.9607477	test: 0.7360000	best: 0.7656250 (72)	total: 2.82s	remaining: 17.4ms
# 162:	learn: 0.9607477	test: 0.7360000	best: 0.7656250 (72)	total: 2.84s	remaining: 0us
#
# bestTest = 0.765625
# bestIteration = 72
#
# Training on fold [3/5]
# 0:	learn: 0.7286822	test: 0.8091603	best: 0.8091603 (0)	total: 11.7ms	remaining: 1.9s
# 1:	learn: 0.7407407	test: 0.8062016	best: 0.8091603 (0)	total: 23.2ms	remaining: 1.86s
# 2:	learn: 0.7599244	test: 0.8030303	best: 0.8091603 (0)	total: 37.3ms	remaining: 1.99s
# 3:	learn: 0.7745665	test: 0.8120301	best: 0.8120301 (3)	total: 54.9ms	remaining: 2.18s
# 4:	learn: 0.7751938	test: 0.8120301	best: 0.8120301 (3)	total: 70.3ms	remaining: 2.22s
# 5:	learn: 0.7837838	test: 0.8088235	best: 0.8120301 (3)	total: 82.9ms	remaining: 2.17s
# 6:	learn: 0.7766990	test: 0.8148148	best: 0.8148148 (6)	total: 97.6ms	remaining: 2.17s
# 7:	learn: 0.7837838	test: 0.7971014	best: 0.8148148 (6)	total: 110ms	remaining: 2.12s
# 8:	learn: 0.7884615	test: 0.7971014	best: 0.8148148 (6)	total: 128ms	remaining: 2.18s
# 9:	learn: 0.8023483	test: 0.7969925	best: 0.8148148 (6)	total: 140ms	remaining: 2.14s
# 10:	learn: 0.8093385	test: 0.7969925	best: 0.8148148 (6)	total: 155ms	remaining: 2.14s
# 11:	learn: 0.8139535	test: 0.7969925	best: 0.8148148 (6)	total: 170ms	remaining: 2.14s
# 12:	learn: 0.8208092	test: 0.7969925	best: 0.8148148 (6)	total: 183ms	remaining: 2.11s
# 13:	learn: 0.8210117	test: 0.8059701	best: 0.8148148 (6)	total: 197ms	remaining: 2.1s
# 14:	learn: 0.8219178	test: 0.8059701	best: 0.8148148 (6)	total: 216ms	remaining: 2.13s
# 15:	learn: 0.8126233	test: 0.8030303	best: 0.8148148 (6)	total: 231ms	remaining: 2.12s
# 16:	learn: 0.8165680	test: 0.7969925	best: 0.8148148 (6)	total: 251ms	remaining: 2.15s
# 17:	learn: 0.8274510	test: 0.8000000	best: 0.8148148 (6)	total: 268ms	remaining: 2.16s
# 18:	learn: 0.8320313	test: 0.8000000	best: 0.8148148 (6)	total: 280ms	remaining: 2.12s
# 19:	learn: 0.8343080	test: 0.8000000	best: 0.8148148 (6)	total: 297ms	remaining: 2.13s
# 20:	learn: 0.8365759	test: 0.8000000	best: 0.8148148 (6)	total: 312ms	remaining: 2.11s
# 21:	learn: 0.8388350	test: 0.8000000	best: 0.8148148 (6)	total: 325ms	remaining: 2.08s
# 22:	learn: 0.8427184	test: 0.7819549	best: 0.8148148 (6)	total: 338ms	remaining: 2.06s
# 23:	learn: 0.8476563	test: 0.7969925	best: 0.8148148 (6)	total: 352ms	remaining: 2.04s
# 24:	learn: 0.8526523	test: 0.8000000	best: 0.8148148 (6)	total: 365ms	remaining: 2.02s
# 25:	learn: 0.8599606	test: 0.7910448	best: 0.8148148 (6)	total: 378ms	remaining: 1.99s
# 26:	learn: 0.8582677	test: 0.7910448	best: 0.8148148 (6)	total: 390ms	remaining: 1.96s
# 27:	learn: 0.8588235	test: 0.8000000	best: 0.8148148 (6)	total: 409ms	remaining: 1.97s
# 28:	learn: 0.8605108	test: 0.8000000	best: 0.8148148 (6)	total: 420ms	remaining: 1.94s
# 29:	learn: 0.8688845	test: 0.7851852	best: 0.8148148 (6)	total: 438ms	remaining: 1.94s
# 30:	learn: 0.8693957	test: 0.7910448	best: 0.8148148 (6)	total: 454ms	remaining: 1.93s
# 31:	learn: 0.8699029	test: 0.7969925	best: 0.8148148 (6)	total: 473ms	remaining: 1.93s
# 32:	learn: 0.8720930	test: 0.7969925	best: 0.8148148 (6)	total: 491ms	remaining: 1.93s
# 33:	learn: 0.8720930	test: 0.7969925	best: 0.8148148 (6)	total: 504ms	remaining: 1.91s
# 34:	learn: 0.8699029	test: 0.7969925	best: 0.8148148 (6)	total: 518ms	remaining: 1.89s
# 35:	learn: 0.8742747	test: 0.7910448	best: 0.8148148 (6)	total: 533ms	remaining: 1.88s
# 36:	learn: 0.8803089	test: 0.7910448	best: 0.8148148 (6)	total: 546ms	remaining: 1.86s
# 37:	learn: 0.8841699	test: 0.7969925	best: 0.8148148 (6)	total: 559ms	remaining: 1.84s
# 38:	learn: 0.8841699	test: 0.7878788	best: 0.8148148 (6)	total: 573ms	remaining: 1.82s
# 39:	learn: 0.8820116	test: 0.7969925	best: 0.8148148 (6)	total: 584ms	remaining: 1.8s
# 40:	learn: 0.8820116	test: 0.7969925	best: 0.8148148 (6)	total: 603ms	remaining: 1.79s
# 41:	learn: 0.8863198	test: 0.7969925	best: 0.8148148 (6)	total: 621ms	remaining: 1.79s
# 42:	learn: 0.8858801	test: 0.7969925	best: 0.8148148 (6)	total: 639ms	remaining: 1.78s
# 43:	learn: 0.8880309	test: 0.7910448	best: 0.8148148 (6)	total: 659ms	remaining: 1.78s
# 44:	learn: 0.8880309	test: 0.7910448	best: 0.8148148 (6)	total: 679ms	remaining: 1.78s
# 45:	learn: 0.8897485	test: 0.7727273	best: 0.8148148 (6)	total: 693ms	remaining: 1.76s
# 46:	learn: 0.8897485	test: 0.7969925	best: 0.8148148 (6)	total: 705ms	remaining: 1.74s
# 47:	learn: 0.8914729	test: 0.7878788	best: 0.8148148 (6)	total: 720ms	remaining: 1.73s
# 48:	learn: 0.8914729	test: 0.8030303	best: 0.8148148 (6)	total: 734ms	remaining: 1.71s
# 49:	learn: 0.8914729	test: 0.7938931	best: 0.8148148 (6)	total: 749ms	remaining: 1.69s
# 50:	learn: 0.8914729	test: 0.7878788	best: 0.8148148 (6)	total: 762ms	remaining: 1.67s
# 51:	learn: 0.8936170	test: 0.7969925	best: 0.8148148 (6)	total: 776ms	remaining: 1.66s
# 52:	learn: 0.8957529	test: 0.7969925	best: 0.8148148 (6)	total: 789ms	remaining: 1.64s
# 53:	learn: 0.8957529	test: 0.7969925	best: 0.8148148 (6)	total: 806ms	remaining: 1.63s
# 54:	learn: 0.8970874	test: 0.8030303	best: 0.8148148 (6)	total: 820ms	remaining: 1.61s
# ...
# 145:	learn: 0.9511278	test: 0.7938931	best: 0.8208955 (60)	total: 2.17s	remaining: 253ms
# 146:	learn: 0.9511278	test: 0.7938931	best: 0.8208955 (60)	total: 2.18s	remaining: 238ms
# 147:	learn: 0.9532710	test: 0.7938931	best: 0.8208955 (60)	total: 2.2s	remaining: 223ms
# 148:	learn: 0.9532710	test: 0.7938931	best: 0.8208955 (60)	total: 2.21s	remaining: 208ms
# 149:	learn: 0.9532710	test: 0.7938931	best: 0.8208955 (60)	total: 2.25s	remaining: 195ms
# 150:	learn: 0.9532710	test: 0.7938931	best: 0.8208955 (60)	total: 2.28s	remaining: 181ms
# 151:	learn: 0.9513109	test: 0.7938931	best: 0.8208955 (60)	total: 2.31s	remaining: 167ms
# 152:	learn: 0.9532710	test: 0.8030303	best: 0.8208955 (60)	total: 2.33s	remaining: 152ms
# 153:	learn: 0.9532710	test: 0.8030303	best: 0.8208955 (60)	total: 2.36s	remaining: 138ms
# 154:	learn: 0.9532710	test: 0.8030303	best: 0.8208955 (60)	total: 2.39s	remaining: 123ms
# 155:	learn: 0.9532710	test: 0.8030303	best: 0.8208955 (60)	total: 2.44s	remaining: 109ms
# 156:	learn: 0.9532710	test: 0.8030303	best: 0.8208955 (60)	total: 2.48s	remaining: 94.8ms
# 157:	learn: 0.9552239	test: 0.8030303	best: 0.8208955 (60)	total: 2.53s	remaining: 80.1ms
# 158:	learn: 0.9552239	test: 0.8030303	best: 0.8208955 (60)	total: 2.56s	remaining: 64.5ms
# 159:	learn: 0.9552239	test: 0.7938931	best: 0.8208955 (60)	total: 2.63s	remaining: 49.4ms
# 160:	learn: 0.9552239	test: 0.7938931	best: 0.8208955 (60)	total: 2.69s	remaining: 33.4ms
# 161:	learn: 0.9552239	test: 0.7938931	best: 0.8208955 (60)	total: 2.71s	remaining: 16.7ms
# 162:	learn: 0.9571695	test: 0.7938931	best: 0.8208955 (60)	total: 2.72s	remaining: 0us
#
# bestTest = 0.8208955224
# bestIteration = 60
#
# Training on fold [4/5]
# 0:	learn: 0.7490494	test: 0.7343750	best: 0.7343750 (0)	total: 12.5ms	remaining: 2.02s
# 1:	learn: 0.7620890	test: 0.7401575	best: 0.7401575 (1)	total: 27ms	remaining: 2.17s
# 2:	learn: 0.7641326	test: 0.7401575	best: 0.7401575 (1)	total: 46.8ms	remaining: 2.5s
# 3:	learn: 0.7656250	test: 0.7401575	best: 0.7401575 (1)	total: 63.6ms	remaining: 2.53s
# 4:	learn: 0.7710372	test: 0.7401575	best: 0.7401575 (1)	total: 81.4ms	remaining: 2.57s
# 5:	learn: 0.7734375	test: 0.7401575	best: 0.7401575 (1)	total: 101ms	remaining: 2.63s
# 6:	learn: 0.7890625	test: 0.7401575	best: 0.7401575 (1)	total: 120ms	remaining: 2.68s
# 7:	learn: 0.7976190	test: 0.7540984	best: 0.7540984 (7)	total: 136ms	remaining: 2.63s
# 8:	learn: 0.7953216	test: 0.7401575	best: 0.7540984 (7)	total: 156ms	remaining: 2.67s
# 9:	learn: 0.7976190	test: 0.7360000	best: 0.7540984 (7)	total: 180ms	remaining: 2.76s
# 10:	learn: 0.8023715	test: 0.7301587	best: 0.7540984 (7)	total: 204ms	remaining: 2.81s
# 11:	learn: 0.8070866	test: 0.7244094	best: 0.7540984 (7)	total: 223ms	remaining: 2.81s
# 12:	learn: 0.8233010	test: 0.7244094	best: 0.7540984 (7)	total: 244ms	remaining: 2.82s
# 13:	learn: 0.8281250	test: 0.7301587	best: 0.7540984 (7)	total: 263ms	remaining: 2.8s
# 14:	learn: 0.8493151	test: 0.7244094	best: 0.7540984 (7)	total: 282ms	remaining: 2.79s
# 15:	learn: 0.8515625	test: 0.7244094	best: 0.7540984 (7)	total: 299ms	remaining: 2.75s
# 16:	learn: 0.8498024	test: 0.7187500	best: 0.7540984 (7)	total: 315ms	remaining: 2.71s
# 17:	learn: 0.8508946	test: 0.7244094	best: 0.7540984 (7)	total: 331ms	remaining: 2.67s
# 18:	learn: 0.8475248	test: 0.7301587	best: 0.7540984 (7)	total: 348ms	remaining: 2.63s
# 19:	learn: 0.8543307	test: 0.7301587	best: 0.7540984 (7)	total: 369ms	remaining: 2.64s
# 20:	learn: 0.8593750	test: 0.7258065	best: 0.7540984 (7)	total: 388ms	remaining: 2.62s
# 21:	learn: 0.8615984	test: 0.7258065	best: 0.7540984 (7)	total: 405ms	remaining: 2.59s
# 22:	learn: 0.8677043	test: 0.7258065	best: 0.7540984 (7)	total: 430ms	remaining: 2.62s
# 23:	learn: 0.8720930	test: 0.7258065	best: 0.7540984 (7)	total: 451ms	remaining: 2.61s
# 24:	learn: 0.8764479	test: 0.7086614	best: 0.7540984 (7)	total: 469ms	remaining: 2.59s
# 25:	learn: 0.8781431	test: 0.7187500	best: 0.7540984 (7)	total: 487ms	remaining: 2.56s
# 26:	learn: 0.8837209	test: 0.7187500	best: 0.7540984 (7)	total: 503ms	remaining: 2.53s
# 27:	learn: 0.8815534	test: 0.7187500	best: 0.7540984 (7)	total: 518ms	remaining: 2.5s
# 28:	learn: 0.8841699	test: 0.7131783	best: 0.7540984 (7)	total: 536ms	remaining: 2.48s
# 29:	learn: 0.8829175	test: 0.6929134	best: 0.7540984 (7)	total: 554ms	remaining: 2.46s
# 30:	learn: 0.8850575	test: 0.6929134	best: 0.7540984 (7)	total: 570ms	remaining: 2.43s
# 31:	learn: 0.8871893	test: 0.6929134	best: 0.7540984 (7)	total: 586ms	remaining: 2.4s
# 32:	learn: 0.8871893	test: 0.7086614	best: 0.7540984 (7)	total: 601ms	remaining: 2.37s
# 33:	learn: 0.8931298	test: 0.7086614	best: 0.7540984 (7)	total: 622ms	remaining: 2.36s
# 34:	learn: 0.8905950	test: 0.7286822	best: 0.7540984 (7)	total: 665ms	remaining: 2.43s
# 35:	learn: 0.8948375	test: 0.7286822	best: 0.7540984 (7)	total: 696ms	remaining: 2.45s
# 36:	learn: 0.8923077	test: 0.7384615	best: 0.7540984 (7)	total: 717ms	remaining: 2.44s
# 37:	learn: 0.8923077	test: 0.7286822	best: 0.7540984 (7)	total: 738ms	remaining: 2.43s
# 38:	learn: 0.8905950	test: 0.7441860	best: 0.7540984 (7)	total: 753ms	remaining: 2.4s
# 39:	learn: 0.8905950	test: 0.7441860	best: 0.7540984 (7)	total: 769ms	remaining: 2.36s
# 40:	learn: 0.8961538	test: 0.7244094	best: 0.7540984 (7)	total: 783ms	remaining: 2.33s
# 41:	learn: 0.8923077	test: 0.7343750	best: 0.7540984 (7)	total: 808ms	remaining: 2.33s
# 42:	learn: 0.8901734	test: 0.7040000	best: 0.7540984 (7)	total: 827ms	remaining: 2.31s
# 43:	learn: 0.8901734	test: 0.7040000	best: 0.7540984 (7)	total: 843ms	remaining: 2.28s
# 44:	learn: 0.8961538	test: 0.7040000	best: 0.7540984 (7)	total: 855ms	remaining: 2.24s
# 45:	learn: 0.8940270	test: 0.7040000	best: 0.7540984 (7)	total: 870ms	remaining: 2.21s
# 46:	learn: 0.9003831	test: 0.7343750	best: 0.7540984 (7)	total: 889ms	remaining: 2.19s
# 47:	learn: 0.9003831	test: 0.7343750	best: 0.7540984 (7)	total: 905ms	remaining: 2.17s
# 48:	learn: 0.9038462	test: 0.7244094	best: 0.7540984 (7)	total: 921ms	remaining: 2.14s
# 49:	learn: 0.9021113	test: 0.7244094	best: 0.7540984 (7)	total: 934ms	remaining: 2.11s
# 50:	learn: 0.9045802	test: 0.7244094	best: 0.7540984 (7)	total: 946ms	remaining: 2.08s
# 51:	learn: 0.9042146	test: 0.7343750	best: 0.7540984 (7)	total: 958ms	remaining: 2.04s
# 52:	learn: 0.9042146	test: 0.7343750	best: 0.7540984 (7)	total: 971ms	remaining: 2.02s
# 53:	learn: 0.9042146	test: 0.7343750	best: 0.7540984 (7)	total: 984ms	remaining: 1.99s
# 54:	learn: 0.9080460	test: 0.7040000	best: 0.7540984 (7)	total: 1s	remaining: 1.97s
# 55:	learn: 0.9080460	test: 0.7040000	best: 0.7540984 (7)	total: 1.01s	remaining: 1.94s
# 56:	learn: 0.9080460	test: 0.7040000	best: 0.7540984 (7)	total: 1.03s	remaining: 1.91s
# 57:	learn: 0.9059501	test: 0.7040000	best: 0.7540984 (7)	total: 1.04s	remaining: 1.89s
# 58:	learn: 0.9055877	test: 0.7096774	best: 0.7540984 (7)	total: 1.05s	remaining: 1.86s
# 59:	learn: 0.9055877	test: 0.7154472	best: 0.7540984 (7)	total: 1.07s	remaining: 1.84s
# 60:	learn: 0.9076923	test: 0.7096774	best: 0.7540984 (7)	total: 1.1s	remaining: 1.83s
# 61:	learn: 0.9115385	test: 0.7154472	best: 0.7540984 (7)	total: 1.12s	remaining: 1.82s
# 62:	learn: 0.9115385	test: 0.7154472	best: 0.7540984 (7)	total: 1.14s	remaining: 1.8s
# 63:	learn: 0.9136276	test: 0.7096774	best: 0.7540984 (7)	total: 1.16s	remaining: 1.79s
# 64:	learn: 0.9136276	test: 0.7154472	best: 0.7540984 (7)	total: 1.18s	remaining: 1.77s
# 65:	learn: 0.9174664	test: 0.7258065	best: 0.7540984 (7)	total: 1.19s	remaining: 1.75s
# 66:	learn: 0.9177820	test: 0.7258065	best: 0.7540984 (7)	total: 1.21s	remaining: 1.73s
# 67:	learn: 0.9239544	test: 0.7154472	best: 0.7540984 (7)	total: 1.22s	remaining: 1.71s
# 68:	learn: 0.9219048	test: 0.7096774	best: 0.7540984 (7)	total: 1.24s	remaining: 1.69s
# 69:	learn: 0.9198473	test: 0.7213115	best: 0.7540984 (7)	total: 1.25s	remaining: 1.67s
# 70:	learn: 0.9239544	test: 0.7154472	best: 0.7540984 (7)	total: 1.27s	remaining: 1.64s
# 71:	learn: 0.9259962	test: 0.7272727	best: 0.7540984 (7)	total: 1.28s	remaining: 1.62s
# 72:	learn: 0.9239544	test: 0.7213115	best: 0.7540984 (7)	total: 1.3s	remaining: 1.6s
# 73:	learn: 0.9259962	test: 0.7107438	best: 0.7540984 (7)	total: 1.31s	remaining: 1.57s
# 74:	learn: 0.9259962	test: 0.7213115	best: 0.7540984 (7)	total: 1.33s	remaining: 1.56s
# 75:	learn: 0.9280303	test: 0.7166667	best: 0.7540984 (7)	total: 1.34s	remaining: 1.54s
# 76:	learn: 0.9259962	test: 0.7166667	best: 0.7540984 (7)	total: 1.35s	remaining: 1.51s
# 77:	learn: 0.9303202	test: 0.7272727	best: 0.7540984 (7)	total: 1.37s	remaining: 1.49s
# 78:	learn: 0.9303202	test: 0.7377049	best: 0.7540984 (7)	total: 1.39s	remaining: 1.47s
# 79:	learn: 0.9323308	test: 0.7377049	best: 0.7540984 (7)	total: 1.41s	remaining: 1.46s
# 80:	learn: 0.9363296	test: 0.7377049	best: 0.7540984 (7)	total: 1.42s	remaining: 1.44s
# 81:	learn: 0.9343340	test: 0.7377049	best: 0.7540984 (7)	total: 1.44s	remaining: 1.42s
# 82:	learn: 0.9360902	test: 0.7272727	best: 0.7540984 (7)	total: 1.45s	remaining: 1.4s
# 83:	learn: 0.9380863	test: 0.7213115	best: 0.7540984 (7)	total: 1.48s	remaining: 1.39s
# 84:	learn: 0.9380863	test: 0.7213115	best: 0.7540984 (7)	total: 1.49s	remaining: 1.37s
# 85:	learn: 0.9360902	test: 0.7107438	best: 0.7540984 (7)	total: 1.52s	remaining: 1.36s
# 86:	learn: 0.9340866	test: 0.7107438	best: 0.7540984 (7)	total: 1.54s	remaining: 1.35s
# 87:	learn: 0.9360902	test: 0.7107438	best: 0.7540984 (7)	total: 1.58s	remaining: 1.35s
# 88:	learn: 0.9360902	test: 0.7049180	best: 0.7540984 (7)	total: 1.6s	remaining: 1.33s
# 89:	learn: 0.9360902	test: 0.6991870	best: 0.7540984 (7)	total: 1.62s	remaining: 1.31s
# 90:	learn: 0.9380863	test: 0.6991870	best: 0.7540984 (7)	total: 1.63s	remaining: 1.29s
# 91:	learn: 0.9400749	test: 0.6991870	best: 0.7540984 (7)	total: 1.64s	remaining: 1.27s
# 92:	learn: 0.9418386	test: 0.6991870	best: 0.7540984 (7)	total: 1.66s	remaining: 1.25s
# 93:	learn: 0.9418386	test: 0.7049180	best: 0.7540984 (7)	total: 1.68s	remaining: 1.23s
# 94:	learn: 0.9418386	test: 0.6991870	best: 0.7540984 (7)	total: 1.69s	remaining: 1.21s
# 95:	learn: 0.9418386	test: 0.6935484	best: 0.7540984 (7)	total: 1.7s	remaining: 1.19s
# 96:	learn: 0.9418386	test: 0.6991870	best: 0.7540984 (7)	total: 1.72s	remaining: 1.17s
# 97:	learn: 0.9418386	test: 0.6880000	best: 0.7540984 (7)	total: 1.74s	remaining: 1.15s
# 98:	learn: 0.9416196	test: 0.6991870	best: 0.7540984 (7)	total: 1.75s	remaining: 1.13s
# 99:	learn: 0.9416196	test: 0.6935484	best: 0.7540984 (7)	total: 1.76s	remaining: 1.11s
# 100:	learn: 0.9453861	test: 0.6935484	best: 0.7540984 (7)	total: 1.78s	remaining: 1.09s
# 101:	learn: 0.9453861	test: 0.6880000	best: 0.7540984 (7)	total: 1.8s	remaining: 1.07s
# 102:	learn: 0.9493433	test: 0.6825397	best: 0.7540984 (7)	total: 1.82s	remaining: 1.06s
# 103:	learn: 0.9495327	test: 0.6825397	best: 0.7540984 (7)	total: 1.84s	remaining: 1.04s
# 104:	learn: 0.9495327	test: 0.6825397	best: 0.7540984 (7)	total: 1.86s	remaining: 1.03s
# 105:	learn: 0.9495327	test: 0.6825397	best: 0.7540984 (7)	total: 1.88s	remaining: 1.01s
# 106:	learn: 0.9495327	test: 0.6825397	best: 0.7540984 (7)	total: 1.9s	remaining: 995ms
# 107:	learn: 0.9513109	test: 0.6880000	best: 0.7540984 (7)	total: 1.92s	remaining: 976ms
# 108:	learn: 0.9513109	test: 0.6880000	best: 0.7540984 (7)	total: 1.93s	remaining: 957ms
# 109:	learn: 0.9513109	test: 0.6991870	best: 0.7540984 (7)	total: 1.95s	remaining: 937ms
# 110:	learn: 0.9532710	test: 0.6991870	best: 0.7540984 (7)	total: 1.96s	remaining: 918ms
# 111:	learn: 0.9532710	test: 0.6991870	best: 0.7540984 (7)	total: 1.97s	remaining: 899ms
# 112:	learn: 0.9532710	test: 0.6991870	best: 0.7540984 (7)	total: 1.99s	remaining: 879ms
# 113:	learn: 0.9532710	test: 0.6991870	best: 0.7540984 (7)	total: 2s	remaining: 860ms
# 114:	learn: 0.9532710	test: 0.6935484	best: 0.7540984 (7)	total: 2.01s	remaining: 841ms
# 115:	learn: 0.9532710	test: 0.6991870	best: 0.7540984 (7)	total: 2.03s	remaining: 822ms
# 116:	learn: 0.9552239	test: 0.6880000	best: 0.7540984 (7)	total: 2.04s	remaining: 803ms
# 117:	learn: 0.9532710	test: 0.6935484	best: 0.7540984 (7)	total: 2.06s	remaining: 785ms
# 118:	learn: 0.9532710	test: 0.6935484	best: 0.7540984 (7)	total: 2.08s	remaining: 767ms
# 119:	learn: 0.9532710	test: 0.6935484	best: 0.7540984 (7)	total: 2.09s	remaining: 749ms
# 120:	learn: 0.9532710	test: 0.6935484	best: 0.7540984 (7)	total: 2.11s	remaining: 731ms
# 121:	learn: 0.9532710	test: 0.6935484	best: 0.7540984 (7)	total: 2.12s	remaining: 713ms
# 122:	learn: 0.9532710	test: 0.6935484	best: 0.7540984 (7)	total: 2.14s	remaining: 696ms
# 123:	learn: 0.9552239	test: 0.6935484	best: 0.7540984 (7)	total: 2.16s	remaining: 680ms
# 124:	learn: 0.9552239	test: 0.6935484	best: 0.7540984 (7)	total: 2.18s	remaining: 663ms
# 125:	learn: 0.9552239	test: 0.6991870	best: 0.7540984 (7)	total: 2.2s	remaining: 645ms
# 126:	learn: 0.9552239	test: 0.6991870	best: 0.7540984 (7)	total: 2.22s	remaining: 628ms
# 127:	learn: 0.9552239	test: 0.6991870	best: 0.7540984 (7)	total: 2.23s	remaining: 611ms
# 128:	learn: 0.9552239	test: 0.6991870	best: 0.7540984 (7)	total: 2.25s	remaining: 594ms
# 129:	learn: 0.9552239	test: 0.6991870	best: 0.7540984 (7)	total: 2.27s	remaining: 576ms
# 130:	learn: 0.9571695	test: 0.6991870	best: 0.7540984 (7)	total: 2.28s	remaining: 558ms
# 131:	learn: 0.9571695	test: 0.6991870	best: 0.7540984 (7)	total: 2.3s	remaining: 539ms
# 132:	learn: 0.9571695	test: 0.6991870	best: 0.7540984 (7)	total: 2.31s	remaining: 521ms
# 133:	learn: 0.9591078	test: 0.6991870	best: 0.7540984 (7)	total: 2.33s	remaining: 504ms
# 134:	learn: 0.9591078	test: 0.6935484	best: 0.7540984 (7)	total: 2.34s	remaining: 486ms
# 135:	learn: 0.9552239	test: 0.6935484	best: 0.7540984 (7)	total: 2.37s	remaining: 471ms
# 136:	learn: 0.9571695	test: 0.6935484	best: 0.7540984 (7)	total: 2.39s	remaining: 453ms
# 137:	learn: 0.9571695	test: 0.6935484	best: 0.7540984 (7)	total: 2.42s	remaining: 438ms
# 138:	learn: 0.9571695	test: 0.6991870	best: 0.7540984 (7)	total: 2.43s	remaining: 420ms
# 139:	learn: 0.9552239	test: 0.6991870	best: 0.7540984 (7)	total: 2.45s	remaining: 402ms
# 140:	learn: 0.9571695	test: 0.6935484	best: 0.7540984 (7)	total: 2.46s	remaining: 385ms
# 141:	learn: 0.9571695	test: 0.6935484	best: 0.7540984 (7)	total: 2.48s	remaining: 367ms
# 142:	learn: 0.9571695	test: 0.7040000	best: 0.7540984 (7)	total: 2.5s	remaining: 349ms
# 143:	learn: 0.9591078	test: 0.7096774	best: 0.7540984 (7)	total: 2.51s	remaining: 331ms
# 144:	learn: 0.9571695	test: 0.7096774	best: 0.7540984 (7)	total: 2.52s	remaining: 313ms
# 145:	learn: 0.9571695	test: 0.7096774	best: 0.7540984 (7)	total: 2.53s	remaining: 295ms
# 146:	learn: 0.9571695	test: 0.7096774	best: 0.7540984 (7)	total: 2.55s	remaining: 277ms
# 147:	learn: 0.9571695	test: 0.7096774	best: 0.7540984 (7)	total: 2.56s	remaining: 260ms
# 148:	learn: 0.9591078	test: 0.7154472	best: 0.7540984 (7)	total: 2.58s	remaining: 242ms
# 149:	learn: 0.9610390	test: 0.7154472	best: 0.7540984 (7)	total: 2.59s	remaining: 224ms
# 150:	learn: 0.9628253	test: 0.7154472	best: 0.7540984 (7)	total: 2.6s	remaining: 207ms
# 151:	learn: 0.9628253	test: 0.7154472	best: 0.7540984 (7)	total: 2.62s	remaining: 189ms
# 152:	learn: 0.9628253	test: 0.7154472	best: 0.7540984 (7)	total: 2.64s	remaining: 172ms
# 153:	learn: 0.9628253	test: 0.7154472	best: 0.7540984 (7)	total: 2.65s	remaining: 155ms
# 154:	learn: 0.9628253	test: 0.7154472	best: 0.7540984 (7)	total: 2.67s	remaining: 138ms
# 155:	learn: 0.9628253	test: 0.7154472	best: 0.7540984 (7)	total: 2.68s	remaining: 120ms
# 156:	learn: 0.9628253	test: 0.7154472	best: 0.7540984 (7)	total: 2.69s	remaining: 103ms
# 157:	learn: 0.9628253	test: 0.7154472	best: 0.7540984 (7)	total: 2.7s	remaining: 85.6ms
# 158:	learn: 0.9628253	test: 0.7154472	best: 0.7540984 (7)	total: 2.72s	remaining: 68.5ms
# 159:	learn: 0.9628253	test: 0.7258065	best: 0.7540984 (7)	total: 2.73s	remaining: 51.3ms
# 160:	learn: 0.9628253	test: 0.7258065	best: 0.7540984 (7)	total: 2.75s	remaining: 34.2ms
# 161:	learn: 0.9666667	test: 0.7258065	best: 0.7540984 (7)	total: 2.77s	remaining: 17.1ms
# 162:	learn: 0.9666667	test: 0.7258065	best: 0.7540984 (7)	total: 2.78s	remaining: 0us
#
# bestTest = 0.7540983607
# bestIteration = 7

# %% [markdown]
# And get the performance plots:

# %%
import plotly.graph_objects as go

# Create figure
fig = go.Figure()

# Add mean performance line
fig.add_trace(
    go.Scatter(
        x=cv_results["iterations"], y=cv_results["test-F1-mean"], mode="lines", name="Mean F1 Score", line=dict(color="blue")
    )
)

# Add shaded error region
fig.add_trace(
    go.Scatter(
        x=pd.concat([cv_results["iterations"], cv_results["iterations"][::-1]]),
        y=pd.concat([cv_results["test-F1-mean"]+cv_results["test-F1-std"], 
                     cv_results["test-F1-mean"]-cv_results["test-F1-std"]]),
        fill="toself", 
        fillcolor="rgba(0, 0, 255, 0.2)",
        line=dict(color="rgba(255, 255, 255, 0)"),
        showlegend=False
    )
)

# Customize layout
fig.update_layout(
    title="Cross-Validation (N=5) Mean F1 score with Error Bands",
    xaxis_title="Training Steps",
    yaxis_title="Performance Score",
    template="plotly_white",
    yaxis=dict(range=[0.5, 1])
)

fig.show()

fig.write_image(outfolder / "test_f1_v2.png")

# %%
import plotly.graph_objects as go

# Create figure
fig = go.Figure()

# Add mean performance line
fig.add_trace(
    go.Scatter(
        x=cv_results["iterations"], y=cv_results["test-Logloss-mean"], mode="lines", name="Mean logloss", line=dict(color="blue")
    )
)

# Add shaded error region
fig.add_trace(
    go.Scatter(
        x=pd.concat([cv_results["iterations"], cv_results["iterations"][::-1]]),
        y=pd.concat([cv_results["test-Logloss-mean"]+cv_results["test-Logloss-std"], 
                     cv_results["test-Logloss-mean"]-cv_results["test-Logloss-std"]]),
        fill="toself", 
        fillcolor="rgba(0, 0, 255, 0.2)",
        line=dict(color="rgba(255, 255, 255, 0)"),
        showlegend=False
    )
)

# Customize layout
fig.update_layout(
    title="Cross-Validation (N=5) Mean Logloss with Error Bands",
    xaxis_title="Training Steps",
    yaxis_title="Logloss",
    template="plotly_white"
)

fig.show()

fig.write_image(outfolder / "test_logloss_v2.png")

# %% [markdown]
# Fit model on full dataset:

# %%
model.fit(
    X_train,
    y_train,
    verbose_eval=50,
    early_stopping_rounds=50,
    cat_features=categorical_indices,
    use_best_model=False,
    plot=True
)

model.save_model(outfolder / 'catboost_model_titanic_v2.cbm')
joblib.dump(params, outfolder / 'model_params_v2.pkl')
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 0.7321429	total: 13.8ms	remaining: 2.23s
# 50:	learn: 0.8535826	total: 1.11s	remaining: 2.43s
# 100:	learn: 0.8813559	total: 1.82s	remaining: 1.12s
# 150:	learn: 0.9115854	total: 2.69s	remaining: 213ms
# 162:	learn: 0.9160305	total: 2.86s	remaining: 0us
# ['results\\model_params_v2.pkl']

# %% [markdown]
# And now to copy paste the train preprocessing code to preprocess the test set, and run a prediction:

# %%
df_test = pd.read_csv(download_folder / "test.csv")
df_test = df_test.drop(columns=["Ticket"])
df_test_id = df_test.pop("PassengerId")
df_test = df_test.fillna({"Embarked": "N", "Age": X_train["Age"].mean()})

pattern = r'([A-Za-z]+)(\d+)'
matches = df_test['Cabin'].str.extractall(pattern)
matches.reset_index(inplace=True)
result = matches.pivot(index='level_0', columns='match', values=[0, 1])
result.columns = [f"{col[0]}_{col[1]}" for col in result.columns]
df_test = df_test.join(result[["0_0", "1_0"]])
df_test["1_0"] = df_test["1_0"].astype(float)
df_test = df_test.fillna({"0_0": "N", "1_0": X_train["CabinNumber"].mean()})
df_test["1_0"] = df_test["1_0"].astype(int)
df_test = df_test.rename(columns={"0_0": "Deck", "1_0": "CabinNumber"})

df_test["Title"] = df_test["Name"].apply(extract_title)

df_test.drop(columns=["Cabin", "Name"], axis=1, inplace=True)
df_test["Title"].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Ms', 'Col', 'Rev', 'Dr', 'Dona'],
#       dtype=object)

# %%
preds = model.predict(df_test[X_train.columns])

# %% [markdown]
# Get the shapley overview plot showing the importance of the new features as well:

# %%
import shap
import matplotlib.pyplot as plt
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(df_test[X_train.columns])

shap.summary_plot(shap_values, df_test, show=False)
plt.savefig(outfolder / "test_shap_overall_v2.png")

# %% [markdown]
# And finally let's get the score on the test set:

# %%
df_test["PassengerId"] = df_test_id
df_test["Survived"] = preds

df_test[["PassengerId", "Survived"]].to_csv(outfolder / "predictions_v2.csv", index=False)

# %% [markdown]
# And submitting again to kaggle we get a slight improvement but with the client happier that we used all the data at least:
#
# ![screenshot of kaggle submission page v2 with prediction performance of 0.76555](results/kaggle_result_v2.png "Kaggle Result")
